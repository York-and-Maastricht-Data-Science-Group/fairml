# %% [markdown]
# # FairML: Tutorial Medical Expenditure<br>
# Medical Expenditure Tutorial. This tutorial demonstrates classification model learning <br>
# with bias mitigation as a part of a Care Management use case <br>
# using Medical Expenditure data.<br>
# https://github.com/Trusted-AI/AIF360/blob/master/examples/tutorial_medical_expenditure.ipynb

# %% [markdown]
# # Contents<br>
# [FairML: Tutorial Medical Expenditure](#FairML:-Tutorial-Medical-Expenditure)<br>
# [Contents](#Contents)<br>
# * [1. Bias Mitigation: Medical Expenditure Bias Mitigation](#1.-Bias-Mitigation:-Medical-Expenditure-Bias-Mitigation)<br>
#   * [1.1. Dataset Panel19-Panel19](#1.1.-Dataset-Panel19-Panel19)<br>
#       * [1.1.1. Original Dataset](#1.1.1.-Original-Dataset)<br>
#           * [1.1.1.1. Classifier LogisticRegression, Parameters: solver='liblinear', random_state=1](#1.1.1.1.-Original-Dataset:-Classifier-LogisticRegression,-Parameters:-solver='liblinear',-random_state=1)<br>
#               * [1.1.1.1.1. Bias Metrics](#1.1.1.1.1.-Original-Dataset:-Bias-Metrics)<br>
#           * [1.1.1.2. Classifier RandomForestClassifier, Parameters: n_estimators=500, min_samples_leaf=25](#1.1.1.2.-Original-Dataset:-Classifier-RandomForestClassifier,-Parameters:-n_estimators=500,-min_samples_leaf=25)<br>
#               * [1.1.1.2.1. Bias Metrics](#1.1.1.2.1.-Original-Dataset:-Bias-Metrics)<br>
#       * [1.1.2. Mitigate Bias using Reweighing](#1.1.2.-Mitigate-Bias-using-Reweighing)<br>
#           * [1.1.2.1. Classifier LogisticRegression, Parameters: solver='liblinear', random_state=1](#1.1.2.1.-After-mitigation-Dataset:-Classifier-LogisticRegression,-Parameters:-solver='liblinear',-random_state=1)<br>
#               * [1.1.2.1.1. Bias Metrics](#1.1.2.1.1.-After-mitigation:-Bias-Metrics)<br>
#           * [1.1.2.2. Classifier RandomForestClassifier, Parameters: n_estimators=500, min_samples_leaf=25](#1.1.2.2.-After-mitigation-Dataset:-Classifier-RandomForestClassifier,-Parameters:-n_estimators=500,-min_samples_leaf=25)<br>
#               * [1.1.2.2.1. Bias Metrics](#1.1.2.2.1.-After-mitigation:-Bias-Metrics)<br>
#       * [1.1.3. Mitigate Bias using PrejudiceRemover](#1.1.3.-Mitigate-Bias-using-PrejudiceRemover)<br>
#           * [1.1.3.1. Classifier PrejudiceRemover, Parameters: sensitive_attr='RACE', eta=25.0](#1.1.3.1.-After-mitigation-Dataset:-Classifier-PrejudiceRemover,-Parameters:-sensitive_attr='RACE',-eta=25.0)<br>
#               * [1.1.3.1.1. Bias Metrics](#1.1.3.1.1.-After-mitigation:-Bias-Metrics)<br>
#   * [1.2. Summary](#1.2.-Summary)<br>
# * [2. Bias Mitigation: Model Deployment](#2.-Bias-Mitigation:-Model-Deployment)<br>
#   * [2.1. Dataset Panel19-Panel19](#2.1.-Dataset-Panel19-Panel19)<br>
#       * [2.1.1. Original Dataset](#2.1.1.-Original-Dataset)<br>
#           * [2.1.1.1. Classifier LogisticRegression, Parameters: solver='liblinear', random_state=1](#2.1.1.1.-Original-Dataset:-Classifier-LogisticRegression,-Parameters:-solver='liblinear',-random_state=1)<br>
#               * [2.1.1.1.1. Bias Metrics](#2.1.1.1.1.-Original-Dataset:-Bias-Metrics)<br>
#       * [2.1.2. Mitigate Bias using Reweighing](#2.1.2.-Mitigate-Bias-using-Reweighing)<br>
#           * [2.1.2.1. Classifier LogisticRegression, Parameters: solver='liblinear', random_state=1](#2.1.2.1.-After-mitigation-Dataset:-Classifier-LogisticRegression,-Parameters:-solver='liblinear',-random_state=1)<br>
#               * [2.1.2.1.1. Bias Metrics](#2.1.2.1.1.-After-mitigation:-Bias-Metrics)<br>
#   * [2.2. Dataset Panel19-Panel20](#2.2.-Dataset-Panel19-Panel20)<br>
#       * [2.2.1. Original Dataset](#2.2.1.-Original-Dataset)<br>
#           * [2.2.1.1. Classifier LogisticRegression, Parameters: solver='liblinear', random_state=1](#2.2.1.1.-Original-Dataset:-Classifier-LogisticRegression,-Parameters:-solver='liblinear',-random_state=1)<br>
#               * [2.2.1.1.1. Bias Metrics](#2.2.1.1.1.-Original-Dataset:-Bias-Metrics)<br>
#       * [2.2.2. Mitigate Bias using Reweighing](#2.2.2.-Mitigate-Bias-using-Reweighing)<br>
#           * [2.2.2.1. Classifier LogisticRegression, Parameters: solver='liblinear', random_state=1](#2.2.2.1.-After-mitigation-Dataset:-Classifier-LogisticRegression,-Parameters:-solver='liblinear',-random_state=1)<br>
#               * [2.2.2.1.1. Bias Metrics](#2.2.2.1.1.-After-mitigation:-Bias-Metrics)<br>
#   * [2.3. Dataset Panel19-Panel21](#2.3.-Dataset-Panel19-Panel21)<br>
#       * [2.3.1. Original Dataset](#2.3.1.-Original-Dataset)<br>
#           * [2.3.1.1. Classifier LogisticRegression, Parameters: solver='liblinear', random_state=1](#2.3.1.1.-Original-Dataset:-Classifier-LogisticRegression,-Parameters:-solver='liblinear',-random_state=1)<br>
#               * [2.3.1.1.1. Bias Metrics](#2.3.1.1.1.-Original-Dataset:-Bias-Metrics)<br>
#       * [2.3.2. Mitigate Bias using Reweighing](#2.3.2.-Mitigate-Bias-using-Reweighing)<br>
#           * [2.3.2.1. Classifier LogisticRegression, Parameters: solver='liblinear', random_state=1](#2.3.2.1.-After-mitigation-Dataset:-Classifier-LogisticRegression,-Parameters:-solver='liblinear',-random_state=1)<br>
#               * [2.3.2.1.1. Bias Metrics](#2.3.2.1.1.-After-mitigation:-Bias-Metrics)<br>
#   * [2.4. Dataset Panel20-Panel20](#2.4.-Dataset-Panel20-Panel20)<br>
#       * [2.4.1. Original Dataset](#2.4.1.-Original-Dataset)<br>
#           * [2.4.1.1. Classifier LogisticRegression, Parameters: solver='liblinear', random_state=1](#2.4.1.1.-Original-Dataset:-Classifier-LogisticRegression,-Parameters:-solver='liblinear',-random_state=1)<br>
#               * [2.4.1.1.1. Bias Metrics](#2.4.1.1.1.-Original-Dataset:-Bias-Metrics)<br>
#       * [2.4.2. Mitigate Bias using Reweighing](#2.4.2.-Mitigate-Bias-using-Reweighing)<br>
#           * [2.4.2.1. Classifier LogisticRegression, Parameters: solver='liblinear', random_state=1](#2.4.2.1.-After-mitigation-Dataset:-Classifier-LogisticRegression,-Parameters:-solver='liblinear',-random_state=1)<br>
#               * [2.4.2.1.1. Bias Metrics](#2.4.2.1.1.-After-mitigation:-Bias-Metrics)<br>
#   * [2.5. Dataset Panel20-Panel21](#2.5.-Dataset-Panel20-Panel21)<br>
#       * [2.5.1. Original Dataset](#2.5.1.-Original-Dataset)<br>
#           * [2.5.1.1. Classifier LogisticRegression, Parameters: solver='liblinear', random_state=1](#2.5.1.1.-Original-Dataset:-Classifier-LogisticRegression,-Parameters:-solver='liblinear',-random_state=1)<br>
#               * [2.5.1.1.1. Bias Metrics](#2.5.1.1.1.-Original-Dataset:-Bias-Metrics)<br>
#       * [2.5.2. Mitigate Bias using Reweighing](#2.5.2.-Mitigate-Bias-using-Reweighing)<br>
#           * [2.5.2.1. Classifier LogisticRegression, Parameters: solver='liblinear', random_state=1](#2.5.2.1.-After-mitigation-Dataset:-Classifier-LogisticRegression,-Parameters:-solver='liblinear',-random_state=1)<br>
#               * [2.5.2.1.1. Bias Metrics](#2.5.2.1.1.-After-mitigation:-Bias-Metrics)<br>
#   * [2.6. Summary](#2.6.-Summary)

# %% [markdown]
# Load dependencies.

# %%
import inspect
import numpy as np
np.random.seed(0)
import pandas as pd
import matplotlib
from fairml import *
from sklearn import tree
from sklearn.tree import *
from sklearn.linear_model import *
from sklearn.svm import *
from sklearn.neighbors import *
from sklearn.naive_bayes import *
from sklearn.neural_network import *
from sklearn.kernel_ridge import *
from sklearn.ensemble import *
from sklearn import metrics
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from aif360.algorithms.preprocessing import *
from aif360.algorithms.inprocessing import *
from aif360.algorithms.postprocessing import *
from aif360.datasets import StandardDataset
from collections import defaultdict
from IPython.display import Markdown, display
from IPython import get_ipython
from aif360.datasets import MEPSDataset19
from aif360.datasets import MEPSDataset20
from aif360.datasets import MEPSDataset21

# %%
fairml = FairML()
def get_fairml():
    return fairml

# %%
print("========================")
print("FairML: Tutorial Medical Expenditure")
print("========================")
print("Description:")
print("Medical Expenditure Tutorial. This tutorial demonstrates classification model learning "+
"with bias mitigation as a part of a Care Management use case "+
"using Medical Expenditure data."+
"https://github.com/Trusted-AI/AIF360/blob/master/examples/tutorial_medical_expenditure.ipynb")
# Out:
# ========================
# FairML: Tutorial Medical Expenditure
# ========================
# Description:
# Medical Expenditure Tutorial. This tutorial demonstrates classification model learning with bias mitigation as a part of a Care Management use case using Medical Expenditure data.https://github.com/Trusted-AI/AIF360/blob/master/examples/tutorial_medical_expenditure.ipynb

# %% [markdown]
# ## [1.](#Contents) Bias Mitigation: Medical Expenditure Bias Mitigation

# %%
np.random.seed(0)
bm = fairml.add_bias_mitigation(BiasMitigation())
bm.name = "Medical Expenditure Bias Mitigation"

# %%
print("")
print("========================")
print("Bias Mitigation: Medical Expenditure Bias Mitigation")
print("------------------------")
# Out:
# ========================
# Bias Mitigation: Medical Expenditure Bias Mitigation
# ------------------------

# %% [markdown]
# ### [1.1.](#Contents) Dataset Panel19-Panel19

# %%
print("")
print("Dataset: Panel19-Panel19")
print("-------------")
# Out:
# Dataset: Panel19-Panel19
# -------------

# %% [markdown]
# #### [1.1.1.](#Contents) Original Dataset

# %%
bm.predicted_attribute = ''
bm.protected_attributes = ['RACE']
bm.features_to_keep = []
bm.favorable_class = 1
bm.privileged_class = 1
bm.unprivileged_class = 0
bm.dropped_attributes = []
bm.na_values = []
bm.training_size = 5.0    
bm.test_size = 2.0
bm.validation_size = 3.0
bm.total_size = bm.training_size + bm.test_size + bm.validation_size
bm.categorical_features = []
bm.default_mappings = None

# %% [markdown]
# Load dataset

# %%
bm.resource = "" 
bm.dataset_original = MEPSDataset19()

# %%
bm.dataset_original_train, bm.dataset_original_valid, bm.dataset_original_test = bm.dataset_original.split([bm.training_size/bm.total_size, (bm.training_size + bm.validation_size)/bm.total_size], shuffle=True)

# %%
bm.privileged_groups = [{bm.protected_attributes[0] : bm.privileged_class}]
bm.unprivileged_groups = [{bm.protected_attributes[0] : bm.unprivileged_class}]

# %%
bm.init_new_result("Original", "", "Panel19-Panel19", "", "")
bm.measure_bias("balanced_accuracy", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("mean_difference", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("average_odds_difference", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("disparate_impact", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("statistical_parity_difference", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("equal_opportunity_difference", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("theil_index", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("accuracy", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
# Out:
# **Metric:** Mean Difference<br/>**Message:** Mean difference (mean label value on unprivileged instances - mean label value on privileged instances): -0.15325088755766275<br/>**NumPositivesUnprivileged:** 1417292.7295189998<br/>**NumInstancesUnprivileged:** 11063999.162326<br/>**NumPositivesPrivileged:** 4807667.433267<br/>**NumInstancesPrivileged:** 17087829.603329003<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:** The ideal value of this metric is 0.0<br/>
# **Metric:** Disparate Impact<br/>**Message:** Disparate impact (probability of favorable outcome for unprivileged instances / probability of favorable outcome for privileged instances): 0.4553023707455683<br/>**NumPositivePredictionsUnprivileged:** 1417292.7295189998<br/>**NumUnprivileged:** 11063999.162326<br/>**NumPositivePredictionsPrivileged:** 4807667.433267<br/>**NumPrivileged:** 17087829.603329003<br/>**Description:** Computed as the ratio of rate of favorable outcome for the unprivileged group to that of the privileged group.<br/>**Ideal:** The ideal value of this metric is 1.0 A value < 1 implies higher benefit for the privileged group and a value >1 implies a higher benefit for the unprivileged group.<br/>
# **Metric:** Statistical Parity Difference<br/>**Message:** Statistical parity difference (probability of favorable outcome for unprivileged instances - probability of favorable outcome for privileged instances): -0.15325088755766275<br/>**NumPositivesUnprivileged:** 1417292.7295189998<br/>**NumInstancesUnprivileged:** 11063999.162326<br/>**NumPositivesPrivileged:** 4807667.433267<br/>**NumInstancesPrivileged:** 17087829.603329003<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:**  The ideal value of this metric is 0<br/>

# %% [markdown]
# ##### [1.1.1.1.](#Contents) Original Dataset: Classifier LogisticRegression, Parameters: solver='liblinear', random_state=1

# %%
print("")
print("Original Dataset: Classifier LogisticRegression, Parameters: solver='liblinear', random_state=1")
print("-------------")
# Out:
# Original Dataset: Classifier LogisticRegression, Parameters: solver='liblinear', random_state=1
# -------------

# %% [markdown]
# Train the model from the original train data

# %%
classifier = LogisticRegression(solver='liblinear', random_state=1)
model_original_train = bm.train(bm.dataset_original_train,  classifier, without_weight=False)

# %% [markdown]
# ###### [1.1.1.1.1.](#Contents) Original Dataset: Bias Metrics

# %%
print("Original Bias Metrics")
# Out:
# Original Bias Metrics

# %%
dataset_original_train_pred = bm.dataset_original_train.copy(deepcopy=True)
dataset_original_valid_pred = bm.dataset_original_valid.copy(deepcopy=True)
dataset_original_test_pred = bm.dataset_original_test.copy(deepcopy=True)

# %%
standard_scaler = StandardScaler()
dataset_original_train_pred_features = standard_scaler.fit_transform(bm.dataset_original_train.features)
dataset_original_valid_pred_features = standard_scaler.fit_transform(bm.dataset_original_valid.features)
dataset_original_test_pred_features = standard_scaler.fit_transform(bm.dataset_original_test.features)

# %%
dataset_original_train_pred = bm.create_predicted_dataset(dataset_original_train_pred, model_original_train)
dataset_original_valid_pred = bm.create_predicted_dataset(dataset_original_valid_pred, model_original_train)
dataset_original_test_pred = bm.create_predicted_dataset(dataset_original_test_pred, model_original_train)

# %%
pos_ind = np.where(model_original_train.classes_ == bm.dataset_original_train.favorable_label)[0][0]
dataset_original_train_pred.scores = model_original_train.predict_proba(dataset_original_train_pred_features)[:,pos_ind].reshape(-1,1)
dataset_original_valid_pred.scores = model_original_train.predict_proba(dataset_original_valid_pred_features)[:,pos_ind].reshape(-1,1)
dataset_original_test_pred.scores = model_original_train.predict_proba(dataset_original_test_pred_features)[:,pos_ind].reshape(-1,1)

# %%
bm.init_new_result("Original", "", "Panel19-Panel19", "LogisticRegression", "solver='liblinear', random_state=1")

# %%
bm.measure_bias("balanced_accuracy", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train,  )
bm.measure_bias("mean_difference", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train,  )
bm.measure_bias("average_odds_difference", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train, plot_threshold=True, )
bm.measure_bias("disparate_impact", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train, plot_threshold=True, )
bm.measure_bias("statistical_parity_difference", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train,  )
bm.measure_bias("equal_opportunity_difference", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train,  )
bm.measure_bias("theil_index", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train,  )
bm.measure_bias("accuracy", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups,   )
# Out:
# **Metric:** Balanced Accuracy<br/>**Message:** Balanced Classification accuracy (BACC): 0.7555879079086228<br/>**TruePositiveRateUnprivileged:** 0.0<br/>**TrueNegativeRateUnprivileged:** 1.0<br/>**TruePositiveRatePrivileged:** 0.0<br/>**TrueNegativeRatePrivileged:** 1.0<br/>**Description:** Return the balanced accuracy of the ratios of true positives and true negatives examples in the dataset, :math:`0.5 * (TPR + TNR)`,  optionally conditioned on protected attributes.<br/>**Ideal:**  The ideal value of this metric is 1<br/>
# **Metric:** Mean Difference<br/>**Message:** Mean difference (mean label value on unprivileged instances - mean label value on privileged instances): -0.2184864464691803<br/>**NumPositivesUnprivileged:** 1417292.7295189998<br/>**NumInstancesUnprivileged:** 11063999.162326<br/>**NumPositivesPrivileged:** 4807667.433267<br/>**NumInstancesPrivileged:** 17087829.603329003<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:** The ideal value of this metric is 0.0<br/>
# **Metric:** Average Odds Difference<br/>**Message:** Average odds difference (average of TPR difference and FPR difference, 0 = equality of odds): -0.1281443004246115<br/>**NumFalsePositivesUnprivileged:** 1349994.1687440001<br/>**NumNegativesUnprivileged:** 9646706.432807<br/>**NumTruePositivesUnprivileged:** 931882.3918899999<br/>**NumPositivesUnprivileged:** 1417292.7295189998<br/>**NumFalsePositivesPrivileged:** 3601759.01681<br/>**NumNegativesPrivileged:** 12280162.170062002<br/>**NumTruePositivesPrivileged:** 3655951.849946<br/>**NumPositivesPrivileged:** 4807667.433267<br/>**Description:** Computed as average difference of false positive rate (false positives / negatives) and true positive rate (true positives / positives) between unprivileged and privileged groups.<br/>**Ideal:** The ideal value of this metric is 0.  A value of < 0 implies higher benefit for the privileged group and a value > 0 implies higher benefit for the unprivileged group.<br/>
# invalid value encountered in double_scalars
# **Metric:** Disparate Impact<br/>**Message:** Disparate impact (probability of favorable outcome for unprivileged instances / probability of favorable outcome for privileged instances): 0.4855872276473075<br/>**NumPositivePredictionsUnprivileged:** 2281876.560634<br/>**NumUnprivileged:** 11063999.162326<br/>**NumPositivePredictionsPrivileged:** 7257710.866756<br/>**NumPrivileged:** 17087829.603329003<br/>**Description:** Computed as the ratio of likelihood of favorable outcome for the unprivileged group to that of the privileged group.<br/>**Ideal:** The ideal value of this metric is 1.0<br/>
# **Metric:** Statistical Parity Difference<br/>**Message:** Statistical parity difference (probability of favorable outcome for unprivileged instances - probability of favorable outcome for privileged instances): -0.2184864464691803<br/>**NumPositivesUnprivileged:** 2281876.560634<br/>**NumInstancesUnprivileged:** 11063999.162326<br/>**NumPositivesPrivileged:** 7257710.866756<br/>**NumInstancesPrivileged:** 17087829.603329003<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:**  The ideal value of this metric is 0<br/>
# **Metric:** True Positive Rate Difference<br/>**Message:** True positive rate difference (true positive rate on unprivileged instances - true positive rate on privileged instances): -0.10293315446391094<br/>**NumTruePositivesUnprivileged:** 931882.3918899999<br/>**NumPositivesUnprivileged:** 1417292.7295189998<br/>**NumTruePositivesPrivileged:** 3655951.849946<br/>**NumPositivesPrivileged:** 4807667.433267<br/>**Description:** This metric is computed as the difference of true positive rates between the unprivileged and the privileged groups.  The true positive rate is the ratio of true positives to the total number of actual positives for a given group.<br/>**Ideal:** The ideal value is 0. A value of < 0 implies higher benefit for the privileged group and a value > 0 implies higher benefit for the unprivileged group.<br/>
# **Metric:** Theil Index<br/>**Message:** Theil index (generalized entropy index with alpha = 1): 0.09333677716536079<br/>**Description:** Computed as the generalized entropy of benefit for all individuals in the dataset, with alpha = 1. It measures the inequality in benefit allocation for individuals.<br/>**Ideal:** A value of 0 implies perfect fairness.<br/>
# **Metric:** Accuracy<br/>**Message:** Classification accuracy (ACC): 0.7788790129904314<br/>**NumTruePositives:** 0.0<br/>**NumTrueNegatives:** 21926868.602868997<br/>**NumPositives:** 6224960.1627859995<br/>**NumNegatives:** 21926868.602868997<br/>**Description:** Computed as (true positive count + true negative count)/(positive_count + negative_count).<br/>**Ideal:** The ideal value of this metric is 1.0<br/>

# %% [markdown]
# ##### [1.1.1.2.](#Contents) Original Dataset: Classifier RandomForestClassifier, Parameters: n_estimators=500, min_samples_leaf=25

# %%
print("")
print("Original Dataset: Classifier RandomForestClassifier, Parameters: n_estimators=500, min_samples_leaf=25")
print("-------------")
# Out:
# Original Dataset: Classifier RandomForestClassifier, Parameters: n_estimators=500, min_samples_leaf=25
# -------------

# %% [markdown]
# Train the model from the original train data

# %%
classifier = RandomForestClassifier(n_estimators=500, min_samples_leaf=25)
model_original_train = bm.train(bm.dataset_original_train,  classifier, without_weight=False)

# %% [markdown]
# ###### [1.1.1.2.1.](#Contents) Original Dataset: Bias Metrics

# %%
print("Original Bias Metrics")
# Out:
# Original Bias Metrics

# %%
dataset_original_train_pred = bm.dataset_original_train.copy(deepcopy=True)
dataset_original_valid_pred = bm.dataset_original_valid.copy(deepcopy=True)
dataset_original_test_pred = bm.dataset_original_test.copy(deepcopy=True)

# %%
standard_scaler = StandardScaler()
dataset_original_train_pred_features = standard_scaler.fit_transform(bm.dataset_original_train.features)
dataset_original_valid_pred_features = standard_scaler.fit_transform(bm.dataset_original_valid.features)
dataset_original_test_pred_features = standard_scaler.fit_transform(bm.dataset_original_test.features)

# %%
dataset_original_train_pred = bm.create_predicted_dataset(dataset_original_train_pred, model_original_train)
dataset_original_valid_pred = bm.create_predicted_dataset(dataset_original_valid_pred, model_original_train)
dataset_original_test_pred = bm.create_predicted_dataset(dataset_original_test_pred, model_original_train)

# %%
pos_ind = np.where(model_original_train.classes_ == bm.dataset_original_train.favorable_label)[0][0]
dataset_original_train_pred.scores = model_original_train.predict_proba(dataset_original_train_pred_features)[:,pos_ind].reshape(-1,1)
dataset_original_valid_pred.scores = model_original_train.predict_proba(dataset_original_valid_pred_features)[:,pos_ind].reshape(-1,1)
dataset_original_test_pred.scores = model_original_train.predict_proba(dataset_original_test_pred_features)[:,pos_ind].reshape(-1,1)

# %%
bm.init_new_result("Original", "", "Panel19-Panel19", "RandomForestClassifier", "n_estimators=500, min_samples_leaf=25")

# %%
bm.measure_bias("balanced_accuracy", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train,  )
bm.measure_bias("mean_difference", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train,  )
bm.measure_bias("average_odds_difference", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train, plot_threshold=True, )
bm.measure_bias("disparate_impact", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train, plot_threshold=True, )
bm.measure_bias("statistical_parity_difference", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train,  )
bm.measure_bias("equal_opportunity_difference", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train,  )
bm.measure_bias("theil_index", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train,  )
bm.measure_bias("accuracy", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups,   )
# Out:
# **Metric:** Balanced Accuracy<br/>**Message:** Balanced Classification accuracy (BACC): 0.7631451879593141<br/>**TruePositiveRateUnprivileged:** 0.0<br/>**TrueNegativeRateUnprivileged:** 1.0<br/>**TruePositiveRatePrivileged:** 0.0<br/>**TrueNegativeRatePrivileged:** 1.0<br/>**Description:** Return the balanced accuracy of the ratios of true positives and true negatives examples in the dataset, :math:`0.5 * (TPR + TNR)`,  optionally conditioned on protected attributes.<br/>**Ideal:**  The ideal value of this metric is 1<br/>
# **Metric:** Mean Difference<br/>**Message:** Mean difference (mean label value on unprivileged instances - mean label value on privileged instances): -0.1796139230926278<br/>**NumPositivesUnprivileged:** 1417292.7295189998<br/>**NumInstancesUnprivileged:** 11063999.162326<br/>**NumPositivesPrivileged:** 4807667.433267<br/>**NumInstancesPrivileged:** 17087829.603329003<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:** The ideal value of this metric is 0.0<br/>
# **Metric:** Average Odds Difference<br/>**Message:** Average odds difference (average of TPR difference and FPR difference, 0 = equality of odds): -0.09649617624373505<br/>**NumFalsePositivesUnprivileged:** 1877193.0595000002<br/>**NumNegativesUnprivileged:** 9646706.432807<br/>**NumTruePositivesUnprivileged:** 1009165.5014480001<br/>**NumPositivesUnprivileged:** 1417292.7295189998<br/>**NumFalsePositivesPrivileged:** 3681884.4998040004<br/>**NumNegativesPrivileged:** 12280162.170062002<br/>**NumTruePositivesPrivileged:** 3845173.5087920004<br/>**NumPositivesPrivileged:** 4807667.433267<br/>**Description:** Computed as average difference of false positive rate (false positives / negatives) and true positive rate (true positives / positives) between unprivileged and privileged groups.<br/>**Ideal:** The ideal value of this metric is 0.  A value of < 0 implies higher benefit for the privileged group and a value > 0 implies higher benefit for the unprivileged group.<br/>
# invalid value encountered in double_scalars
# **Metric:** Disparate Impact<br/>**Message:** Disparate impact (probability of favorable outcome for unprivileged instances / probability of favorable outcome for privileged instances): 0.5922427980909429<br/>**NumPositivePredictionsUnprivileged:** 2886358.560948<br/>**NumUnprivileged:** 11063999.162326<br/>**NumPositivePredictionsPrivileged:** 7527058.008596<br/>**NumPrivileged:** 17087829.603329003<br/>**Description:** Computed as the ratio of likelihood of favorable outcome for the unprivileged group to that of the privileged group.<br/>**Ideal:** The ideal value of this metric is 1.0<br/>
# **Metric:** Statistical Parity Difference<br/>**Message:** Statistical parity difference (probability of favorable outcome for unprivileged instances - probability of favorable outcome for privileged instances): -0.1796139230926278<br/>**NumPositivesUnprivileged:** 2886358.560948<br/>**NumInstancesUnprivileged:** 11063999.162326<br/>**NumPositivesPrivileged:** 7527058.008596<br/>**NumInstancesPrivileged:** 17087829.603329003<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:**  The ideal value of this metric is 0<br/>
# **Metric:** True Positive Rate Difference<br/>**Message:** True positive rate difference (true positive rate on unprivileged instances - true positive rate on privileged instances): -0.08776277760475704<br/>**NumTruePositivesUnprivileged:** 1009165.5014480001<br/>**NumPositivesUnprivileged:** 1417292.7295189998<br/>**NumTruePositivesPrivileged:** 3845173.5087920004<br/>**NumPositivesPrivileged:** 4807667.433267<br/>**Description:** This metric is computed as the difference of true positive rates between the unprivileged and the privileged groups.  The true positive rate is the ratio of true positives to the total number of actual positives for a given group.<br/>**Ideal:** The ideal value is 0. A value of < 0 implies higher benefit for the privileged group and a value > 0 implies higher benefit for the unprivileged group.<br/>
# **Metric:** Theil Index<br/>**Message:** Theil index (generalized entropy index with alpha = 1): 0.09062845726855615<br/>**Description:** Computed as the generalized entropy of benefit for all individuals in the dataset, with alpha = 1. It measures the inequality in benefit allocation for individuals.<br/>**Ideal:** A value of 0 implies perfect fairness.<br/>
# **Metric:** Accuracy<br/>**Message:** Classification accuracy (ACC): 0.7788790129904314<br/>**NumTruePositives:** 0.0<br/>**NumTrueNegatives:** 21926868.602868997<br/>**NumPositives:** 6224960.1627859995<br/>**NumNegatives:** 21926868.602868997<br/>**Description:** Computed as (true positive count + true negative count)/(positive_count + negative_count).<br/>**Ideal:** The ideal value of this metric is 1.0<br/>

# %% [markdown]
# #### [1.1.2.](#Contents) Mitigate Bias using Reweighing

# %%
print("")
print("Mitigate Bias using Reweighing")
print("-------------")
mitigation_method = bm.create_mitigation_method(Reweighing, )
mitigation_method = mitigation_method.fit(bm.dataset_original_train, )
dataset_mitigated_train = mitigation_method.transform(bm.dataset_original_train)
dataset_mitigated_valid = mitigation_method.transform(bm.dataset_original_valid)
dataset_mitigated_test = bm.dataset_original_test
# Out:
# Mitigate Bias using Reweighing
# -------------

# %% [markdown]
# ##### [1.1.2.1.](#Contents) After-mitigation Dataset: Classifier LogisticRegression, Parameters: solver='liblinear', random_state=1

# %%
print("")
print("After-mitigation Training: LogisticRegression, Parameters: solver='liblinear', random_state=1")
print("-------------")
# Out:
# After-mitigation Training: LogisticRegression, Parameters: solver='liblinear', random_state=1
# -------------

# %% [markdown]
# Train the model from the after-mitigation train data

# %%
classifier = LogisticRegression(solver='liblinear', random_state=1)
model_mitigated_train = bm.train(dataset_mitigated_train,  classifier, without_weight=False)

# %% [markdown]
# ###### [1.1.2.1.1.](#Contents) After-mitigation: Bias Metrics

# %%
print("After-mitigation Metrics")
dataset_mitigated_train_pred = bm.create_predicted_dataset(dataset_mitigated_train, model_mitigated_train)
dataset_mitigated_valid_pred = bm.create_predicted_dataset(dataset_mitigated_valid, model_mitigated_train)
dataset_mitigated_test_pred = bm.create_predicted_dataset(dataset_mitigated_test, model_mitigated_train)
# Out:
# After-mitigation Metrics

# %%
bm.init_new_result("Reweighing", "", "Panel19-Panel19", "LogisticRegression", "solver='liblinear', random_state=1")

# %%
bm.measure_bias("balanced_accuracy", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("mean_difference", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("average_odds_difference", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train, plot_threshold=True, )
bm.measure_bias("disparate_impact", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train, plot_threshold=True, )
bm.measure_bias("statistical_parity_difference", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("equal_opportunity_difference", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("theil_index", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("accuracy", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups,   )
# Out:
# **Metric:** Balanced Accuracy<br/>**Message:** Balanced Classification accuracy (BACC): 0.7519272229056848<br/>**TruePositiveRateUnprivileged:** 0.0<br/>**TrueNegativeRateUnprivileged:** 1.0<br/>**TruePositiveRatePrivileged:** 0.0<br/>**TrueNegativeRatePrivileged:** 1.0<br/>**Description:** Return the balanced accuracy of the ratios of true positives and true negatives examples in the dataset, :math:`0.5 * (TPR + TNR)`,  optionally conditioned on protected attributes.<br/>**Ideal:**  The ideal value of this metric is 1<br/>
# **Metric:** Mean Difference<br/>**Message:** Mean difference (mean label value on unprivileged instances - mean label value on privileged instances): -0.05974060268016351<br/>**NumPositivesUnprivileged:** 1417292.7295189998<br/>**NumInstancesUnprivileged:** 11063999.162326<br/>**NumPositivesPrivileged:** 4807667.433267<br/>**NumInstancesPrivileged:** 17087829.603329003<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:** The ideal value of this metric is 0.0<br/>
# **Metric:** Average Odds Difference<br/>**Message:** Average odds difference (average of TPR difference and FPR difference, 0 = equality of odds): 0.04090712529127909<br/>**NumFalsePositivesUnprivileged:** 1718425.0672229999<br/>**NumNegativesUnprivileged:** 9646706.432807<br/>**NumTruePositivesUnprivileged:** 1043945.7571030001<br/>**NumPositivesUnprivileged:** 1417292.7295189998<br/>**NumFalsePositivesPrivileged:** 2108275.163295<br/>**NumNegativesPrivileged:** 12280162.170062002<br/>**NumTruePositivesPrivileged:** 3178914.7077629995<br/>**NumPositivesPrivileged:** 4807667.433267<br/>**Description:** Computed as average difference of false positive rate (false positives / negatives) and true positive rate (true positives / positives) between unprivileged and privileged groups.<br/>**Ideal:** The ideal value of this metric is 0.  A value of < 0 implies higher benefit for the privileged group and a value > 0 implies higher benefit for the unprivileged group.<br/>
# divide by zero encountered in double_scalars
# invalid value encountered in double_scalars
# **Metric:** Disparate Impact<br/>**Message:** Disparate impact (probability of favorable outcome for unprivileged instances / probability of favorable outcome for privileged instances): 0.8069225308917196<br/>**NumPositivePredictionsUnprivileged:** 2762370.824326<br/>**NumUnprivileged:** 11063999.162326<br/>**NumPositivePredictionsPrivileged:** 5287189.871058<br/>**NumPrivileged:** 17087829.603329003<br/>**Description:** Computed as the ratio of likelihood of favorable outcome for the unprivileged group to that of the privileged group.<br/>**Ideal:** The ideal value of this metric is 1.0<br/>
# **Metric:** Statistical Parity Difference<br/>**Message:** Statistical parity difference (probability of favorable outcome for unprivileged instances - probability of favorable outcome for privileged instances): -0.05974060268016351<br/>**NumPositivesUnprivileged:** 2762370.824326<br/>**NumInstancesUnprivileged:** 11063999.162326<br/>**NumPositivesPrivileged:** 5287189.871058<br/>**NumInstancesPrivileged:** 17087829.603329003<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:**  The ideal value of this metric is 0<br/>
# **Metric:** True Positive Rate Difference<br/>**Message:** True positive rate difference (true positive rate on unprivileged instances - true positive rate on privileged instances): 0.07535969386841945<br/>**NumTruePositivesUnprivileged:** 1043945.7571030001<br/>**NumPositivesUnprivileged:** 1417292.7295189998<br/>**NumTruePositivesPrivileged:** 3178914.7077629995<br/>**NumPositivesPrivileged:** 4807667.433267<br/>**Description:** This metric is computed as the difference of true positive rates between the unprivileged and the privileged groups.  The true positive rate is the ratio of true positives to the total number of actual positives for a given group.<br/>**Ideal:** The ideal value is 0. A value of < 0 implies higher benefit for the privileged group and a value > 0 implies higher benefit for the unprivileged group.<br/>
# **Metric:** Theil Index<br/>**Message:** Theil index (generalized entropy index with alpha = 1): 0.09516435065103866<br/>**Description:** Computed as the generalized entropy of benefit for all individuals in the dataset, with alpha = 1. It measures the inequality in benefit allocation for individuals.<br/>**Ideal:** A value of 0 implies perfect fairness.<br/>
# **Metric:** Accuracy<br/>**Message:** Classification accuracy (ACC): 0.7788790129904314<br/>**NumTruePositives:** 0.0<br/>**NumTrueNegatives:** 21926868.602868997<br/>**NumPositives:** 6224960.1627859995<br/>**NumNegatives:** 21926868.602868997<br/>**Description:** Computed as (true positive count + true negative count)/(positive_count + negative_count).<br/>**Ideal:** The ideal value of this metric is 1.0<br/>

# %% [markdown]
# ##### [1.1.2.2.](#Contents) After-mitigation Dataset: Classifier RandomForestClassifier, Parameters: n_estimators=500, min_samples_leaf=25

# %%
print("")
print("After-mitigation Training: RandomForestClassifier, Parameters: n_estimators=500, min_samples_leaf=25")
print("-------------")
# Out:
# After-mitigation Training: RandomForestClassifier, Parameters: n_estimators=500, min_samples_leaf=25
# -------------

# %% [markdown]
# Train the model from the after-mitigation train data

# %%
classifier = RandomForestClassifier(n_estimators=500, min_samples_leaf=25)
model_mitigated_train = bm.train(dataset_mitigated_train,  classifier, without_weight=False)

# %% [markdown]
# ###### [1.1.2.2.1.](#Contents) After-mitigation: Bias Metrics

# %%
print("After-mitigation Metrics")
dataset_mitigated_train_pred = bm.create_predicted_dataset(dataset_mitigated_train, model_mitigated_train)
dataset_mitigated_valid_pred = bm.create_predicted_dataset(dataset_mitigated_valid, model_mitigated_train)
dataset_mitigated_test_pred = bm.create_predicted_dataset(dataset_mitigated_test, model_mitigated_train)
# Out:
# After-mitigation Metrics

# %%
bm.init_new_result("Reweighing", "", "Panel19-Panel19", "RandomForestClassifier", "n_estimators=500, min_samples_leaf=25")

# %%
bm.measure_bias("balanced_accuracy", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("mean_difference", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("average_odds_difference", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train, plot_threshold=True, )
bm.measure_bias("disparate_impact", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train, plot_threshold=True, )
bm.measure_bias("statistical_parity_difference", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("equal_opportunity_difference", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("theil_index", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("accuracy", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups,   )
# Out:
# **Metric:** Balanced Accuracy<br/>**Message:** Balanced Classification accuracy (BACC): 0.7592085843923324<br/>**TruePositiveRateUnprivileged:** 0.0<br/>**TrueNegativeRateUnprivileged:** 1.0<br/>**TruePositiveRatePrivileged:** 0.0<br/>**TrueNegativeRatePrivileged:** 1.0<br/>**Description:** Return the balanced accuracy of the ratios of true positives and true negatives examples in the dataset, :math:`0.5 * (TPR + TNR)`,  optionally conditioned on protected attributes.<br/>**Ideal:**  The ideal value of this metric is 1<br/>
# **Metric:** Mean Difference<br/>**Message:** Mean difference (mean label value on unprivileged instances - mean label value on privileged instances): -0.14834641384474778<br/>**NumPositivesUnprivileged:** 1417292.7295189998<br/>**NumInstancesUnprivileged:** 11063999.162326<br/>**NumPositivesPrivileged:** 4807667.433267<br/>**NumInstancesPrivileged:** 17087829.603329003<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:** The ideal value of this metric is 0.0<br/>
# **Metric:** Average Odds Difference<br/>**Message:** Average odds difference (average of TPR difference and FPR difference, 0 = equality of odds): -0.05394468690311849<br/>**NumFalsePositivesUnprivileged:** 2278985.69489<br/>**NumNegativesUnprivileged:** 9646706.432807<br/>**NumTruePositivesUnprivileged:** 1102533.7565549999<br/>**NumPositivesUnprivileged:** 1417292.7295189998<br/>**NumFalsePositivesPrivileged:** 3883435.12761<br/>**NumNegativesPrivileged:** 12280162.170062002<br/>**NumTruePositivesPrivileged:** 3874081.863663<br/>**NumPositivesPrivileged:** 4807667.433267<br/>**Description:** Computed as average difference of false positive rate (false positives / negatives) and true positive rate (true positives / positives) between unprivileged and privileged groups.<br/>**Ideal:** The ideal value of this metric is 0.  A value of < 0 implies higher benefit for the privileged group and a value > 0 implies higher benefit for the unprivileged group.<br/>
# invalid value encountered in double_scalars
# **Metric:** Disparate Impact<br/>**Message:** Disparate impact (probability of favorable outcome for unprivileged instances / probability of favorable outcome for privileged instances): 0.6732307199719069<br/>**NumPositivePredictionsUnprivileged:** 3381519.451445<br/>**NumUnprivileged:** 11063999.162326<br/>**NumPositivePredictionsPrivileged:** 7757516.991272999<br/>**NumPrivileged:** 17087829.603329003<br/>**Description:** Computed as the ratio of likelihood of favorable outcome for the unprivileged group to that of the privileged group.<br/>**Ideal:** The ideal value of this metric is 1.0<br/>
# **Metric:** Statistical Parity Difference<br/>**Message:** Statistical parity difference (probability of favorable outcome for unprivileged instances - probability of favorable outcome for privileged instances): -0.14834641384474778<br/>**NumPositivesUnprivileged:** 3381519.451445<br/>**NumInstancesUnprivileged:** 11063999.162326<br/>**NumPositivesPrivileged:** 7757516.991272999<br/>**NumInstancesPrivileged:** 17087829.603329003<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:**  The ideal value of this metric is 0<br/>
# **Metric:** True Positive Rate Difference<br/>**Message:** True positive rate difference (true positive rate on unprivileged instances - true positive rate on privileged instances): -0.027897856123346942<br/>**NumTruePositivesUnprivileged:** 1102533.7565549999<br/>**NumPositivesUnprivileged:** 1417292.7295189998<br/>**NumTruePositivesPrivileged:** 3874081.863663<br/>**NumPositivesPrivileged:** 4807667.433267<br/>**Description:** This metric is computed as the difference of true positive rates between the unprivileged and the privileged groups.  The true positive rate is the ratio of true positives to the total number of actual positives for a given group.<br/>**Ideal:** The ideal value is 0. A value of < 0 implies higher benefit for the privileged group and a value > 0 implies higher benefit for the unprivileged group.<br/>
# **Metric:** Theil Index<br/>**Message:** Theil index (generalized entropy index with alpha = 1): 0.08781871278349028<br/>**Description:** Computed as the generalized entropy of benefit for all individuals in the dataset, with alpha = 1. It measures the inequality in benefit allocation for individuals.<br/>**Ideal:** A value of 0 implies perfect fairness.<br/>
# **Metric:** Accuracy<br/>**Message:** Classification accuracy (ACC): 0.7788790129904314<br/>**NumTruePositives:** 0.0<br/>**NumTrueNegatives:** 21926868.602868997<br/>**NumPositives:** 6224960.1627859995<br/>**NumNegatives:** 21926868.602868997<br/>**Description:** Computed as (true positive count + true negative count)/(positive_count + negative_count).<br/>**Ideal:** The ideal value of this metric is 1.0<br/>

# %% [markdown]
# #### [1.1.3.](#Contents) Mitigate Bias using PrejudiceRemover

# %%
print("")
print("Mitigate Bias using PrejudiceRemover")
print("-------------")
dataset_mitigated_train = bm.dataset_original_train.copy(deepcopy=True)
dataset_mitigated_valid = bm.dataset_original_valid.copy(deepcopy=True)
dataset_mitigated_test = bm.dataset_original_test.copy(deepcopy=True)
min_max_scaler = MaxAbsScaler()
dataset_mitigated_train.features = min_max_scaler.fit_transform(bm.dataset_original_train.features)
dataset_mitigated_valid.features = min_max_scaler.fit_transform(bm.dataset_original_valid.features)
dataset_mitigated_test.features = min_max_scaler.fit_transform(bm.dataset_original_test.features)
# Out:
# Mitigate Bias using PrejudiceRemover
# -------------

# %% [markdown]
# ##### [1.1.3.1.](#Contents) After-mitigation Dataset: Classifier PrejudiceRemover, Parameters: sensitive_attr='RACE', eta=25.0

# %%
print("")
print("After-mitigation Training: PrejudiceRemover, Parameters: sensitive_attr='RACE', eta=25.0")
print("-------------")
# Out:
# After-mitigation Training: PrejudiceRemover, Parameters: sensitive_attr='RACE', eta=25.0
# -------------

# %% [markdown]
# Train the model from the after-mitigation train data

# %%
classifier = bm.create_mitigation_method(PrejudiceRemover, sensitive_attr='RACE', eta=25.0)
model_mitigated_train = classifier.fit(dataset_mitigated_train, )

# %% [markdown]
# ###### [1.1.3.1.1.](#Contents) After-mitigation: Bias Metrics

# %%
print("After-mitigation Metrics")
dataset_mitigated_train_pred = model_mitigated_train.predict(dataset_mitigated_train, )
dataset_mitigated_valid_pred = model_mitigated_train.predict(dataset_mitigated_valid, )
dataset_mitigated_test_pred = model_mitigated_train.predict(dataset_mitigated_test, )
# Out:
# After-mitigation Metrics

# %%
bm.init_new_result("PrejudiceRemover", "sensitive_attr='RACE', eta=25.0", "Panel19-Panel19", "PrejudiceRemover", "sensitive_attr='RACE', eta=25.0")

# %%
bm.measure_bias("balanced_accuracy", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("mean_difference", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("average_odds_difference", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train, plot_threshold=True, )
bm.measure_bias("disparate_impact", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train, plot_threshold=True, )
bm.measure_bias("statistical_parity_difference", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("equal_opportunity_difference", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("theil_index", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("accuracy", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups,   )
# Out:
# **Metric:** Balanced Accuracy<br/>**Message:** Balanced Classification accuracy (BACC): 0.7511559355842146<br/>**TruePositiveRateUnprivileged:** 0.0<br/>**TrueNegativeRateUnprivileged:** 1.0<br/>**TruePositiveRatePrivileged:** 0.0<br/>**TrueNegativeRatePrivileged:** 1.0<br/>**Description:** Return the balanced accuracy of the ratios of true positives and true negatives examples in the dataset, :math:`0.5 * (TPR + TNR)`,  optionally conditioned on protected attributes.<br/>**Ideal:**  The ideal value of this metric is 1<br/>
# **Metric:** Mean Difference<br/>**Message:** Mean difference (mean label value on unprivileged instances - mean label value on privileged instances): -0.14486688845669612<br/>**NumPositivesUnprivileged:** 1417292.7295189998<br/>**NumInstancesUnprivileged:** 11063999.162326<br/>**NumPositivesPrivileged:** 4807667.433267<br/>**NumInstancesPrivileged:** 17087829.603329003<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:** The ideal value of this metric is 0.0<br/>
# **Metric:** Average Odds Difference<br/>**Message:** Average odds difference (average of TPR difference and FPR difference, 0 = equality of odds): -0.030966370963443207<br/>**NumFalsePositivesUnprivileged:** 1244896.255106<br/>**NumNegativesUnprivileged:** 9646706.432807<br/>**NumTruePositivesUnprivileged:** 997156.817185<br/>**NumPositivesUnprivileged:** 1417292.7295189998<br/>**NumFalsePositivesPrivileged:** 2691082.0484539997<br/>**NumNegativesPrivileged:** 12280162.170062002<br/>**NumTruePositivesPrivileged:** 3247124.8390140003<br/>**NumPositivesPrivileged:** 4807667.433267<br/>**Description:** Computed as average difference of false positive rate (false positives / negatives) and true positive rate (true positives / positives) between unprivileged and privileged groups.<br/>**Ideal:** The ideal value of this metric is 0.  A value of < 0 implies higher benefit for the privileged group and a value > 0 implies higher benefit for the unprivileged group.<br/>
# divide by zero encountered in double_scalars
# invalid value encountered in double_scalars
# **Metric:** Disparate Impact<br/>**Message:** Disparate impact (probability of favorable outcome for unprivileged instances / probability of favorable outcome for privileged instances): 0.5831299326507623<br/>**NumPositivePredictionsUnprivileged:** 2242053.072291<br/>**NumUnprivileged:** 11063999.162326<br/>**NumPositivePredictionsPrivileged:** 5938206.887468<br/>**NumPrivileged:** 17087829.603329003<br/>**Description:** Computed as the ratio of likelihood of favorable outcome for the unprivileged group to that of the privileged group.<br/>**Ideal:** The ideal value of this metric is 1.0<br/>
# **Metric:** Statistical Parity Difference<br/>**Message:** Statistical parity difference (probability of favorable outcome for unprivileged instances - probability of favorable outcome for privileged instances): -0.14486688845669612<br/>**NumPositivesUnprivileged:** 2242053.072291<br/>**NumInstancesUnprivileged:** 11063999.162326<br/>**NumPositivesPrivileged:** 5938206.887468<br/>**NumInstancesPrivileged:** 17087829.603329003<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:**  The ideal value of this metric is 0<br/>
# **Metric:** True Positive Rate Difference<br/>**Message:** True positive rate difference (true positive rate on unprivileged instances - true positive rate on privileged instances): 0.02815901544297217<br/>**NumTruePositivesUnprivileged:** 997156.817185<br/>**NumPositivesUnprivileged:** 1417292.7295189998<br/>**NumTruePositivesPrivileged:** 3247124.8390140003<br/>**NumPositivesPrivileged:** 4807667.433267<br/>**Description:** This metric is computed as the difference of true positive rates between the unprivileged and the privileged groups.  The true positive rate is the ratio of true positives to the total number of actual positives for a given group.<br/>**Ideal:** The ideal value is 0. A value of < 0 implies higher benefit for the privileged group and a value > 0 implies higher benefit for the unprivileged group.<br/>
# **Metric:** Theil Index<br/>**Message:** Theil index (generalized entropy index with alpha = 1): 0.09545658680671507<br/>**Description:** Computed as the generalized entropy of benefit for all individuals in the dataset, with alpha = 1. It measures the inequality in benefit allocation for individuals.<br/>**Ideal:** A value of 0 implies perfect fairness.<br/>
# **Metric:** Accuracy<br/>**Message:** Classification accuracy (ACC): 0.7788790129904314<br/>**NumTruePositives:** 0.0<br/>**NumTrueNegatives:** 21926868.602868997<br/>**NumPositives:** 6224960.1627859995<br/>**NumNegatives:** 21926868.602868997<br/>**Description:** Computed as (true positive count + true negative count)/(positive_count + negative_count).<br/>**Ideal:** The ideal value of this metric is 1.0<br/>

# %% [markdown]
# ### [1.2.](#Contents) Summary

# %%
table = bm.display_summary()
table.style.set_caption("Worst = White, Best = Green, Mid = Yellow") \
    .apply(bm.highlight_fairest_values, axis=1)
# Out:
# **Description:**<br/>Original Data size: 15830</br>Predicted attribute: </br>Protected attributes: RACE</br>Favourable classes: 1</br>Dropped attributes:  </br>Training data size (ratio): 5.0</br>Test data size (ratio): 2.0</br>Validation data size (ratio): 3.0
# **LogisticRegression:**<details><br/>    Logistic Regression (aka logit, MaxEnt) classifier.<br/><br/>    In the multiclass case, the training algorithm uses the one-vs-rest (OvR)<br/>    scheme if the 'multi_class' option is set to 'ovr', and uses the<br/>    cross-entropy loss if the 'multi_class' option is set to 'multinomial'.<br/>    (Currently the 'multinomial' option is supported only by the 'lbfgs',<br/>    'sag', 'saga' and 'newton-cg' solvers.)<br/><br/>    This class implements regularized logistic regression using the<br/>    'liblinear' library, 'newton-cg', 'sag', 'saga' and 'lbfgs' solvers. **Note<br/>    that regularization is applied by default**. It can handle both dense<br/>    and sparse input. Use C-ordered arrays or CSR matrices containing 64-bit<br/>    floats for optimal performance; any other input format will be converted<br/>    (and copied).<br/><br/>    The 'newton-cg', 'sag', and 'lbfgs' solvers support only L2 regularization<br/>    with primal formulation, or no regularization. The 'liblinear' solver<br/>    supports both L1 and L2 regularization, with a dual formulation only for<br/>    the L2 penalty. The Elastic-Net regularization is only supported by the<br/>    'saga' solver.<br/><br/>    Read more in the :ref:`User Guide <logistic_regression>`.<br/><br/>    Parameters<br/>    ----------<br/>    penalty : {'l1', 'l2', 'elasticnet', 'none'}, default='l2'<br/>        Specify the norm of the penalty:<br/><br/>        - `'none'`: no penalty is added;<br/>        - `'l2'`: add a L2 penalty term and it is the default choice;<br/>        - `'l1'`: add a L1 penalty term;<br/>        - `'elasticnet'`: both L1 and L2 penalty terms are added.<br/><br/>        .. warning::<br/>           Some penalties may not work with some solvers. See the parameter<br/>           `solver` below, to know the compatibility between the penalty and<br/>           solver.<br/><br/>        .. versionadded:: 0.19<br/>           l1 penalty with SAGA solver (allowing 'multinomial' + L1)<br/><br/>    dual : bool, default=False<br/>        Dual or primal formulation. Dual formulation is only implemented for<br/>        l2 penalty with liblinear solver. Prefer dual=False when<br/>        n_samples > n_features.<br/><br/>    tol : float, default=1e-4<br/>        Tolerance for stopping criteria.<br/><br/>    C : float, default=1.0<br/>        Inverse of regularization strength; must be a positive float.<br/>        Like in support vector machines, smaller values specify stronger<br/>        regularization.<br/><br/>    fit_intercept : bool, default=True<br/>        Specifies if a constant (a.k.a. bias or intercept) should be<br/>        added to the decision function.<br/><br/>    intercept_scaling : float, default=1<br/>        Useful only when the solver 'liblinear' is used<br/>        and self.fit_intercept is set to True. In this case, x becomes<br/>        [x, self.intercept_scaling],<br/>        i.e. a "synthetic" feature with constant value equal to<br/>        intercept_scaling is appended to the instance vector.<br/>        The intercept becomes ``intercept_scaling * synthetic_feature_weight``.<br/><br/>        Note! the synthetic feature weight is subject to l1/l2 regularization<br/>        as all other features.<br/>        To lessen the effect of regularization on synthetic feature weight<br/>        (and therefore on the intercept) intercept_scaling has to be increased.<br/><br/>    class_weight : dict or 'balanced', default=None<br/>        Weights associated with classes in the form ``{class_label: weight}``.<br/>        If not given, all classes are supposed to have weight one.<br/><br/>        The "balanced" mode uses the values of y to automatically adjust<br/>        weights inversely proportional to class frequencies in the input data<br/>        as ``n_samples / (n_classes * np.bincount(y))``.<br/><br/>        Note that these weights will be multiplied with sample_weight (passed<br/>        through the fit me ...
# **RandomForestClassifier:**<details><br/>    A random forest classifier.<br/><br/>    A random forest is a meta estimator that fits a number of decision tree<br/>    classifiers on various sub-samples of the dataset and uses averaging to<br/>    improve the predictive accuracy and control over-fitting.<br/>    The sub-sample size is controlled with the `max_samples` parameter if<br/>    `bootstrap=True` (default), otherwise the whole dataset is used to build<br/>    each tree.<br/><br/>    Read more in the :ref:`User Guide <forest>`.<br/><br/>    Parameters<br/>    ----------<br/>    n_estimators : int, default=100<br/>        The number of trees in the forest.<br/><br/>        .. versionchanged:: 0.22<br/>           The default value of ``n_estimators`` changed from 10 to 100<br/>           in 0.22.<br/><br/>    criterion : {"gini", "entropy"}, default="gini"<br/>        The function to measure the quality of a split. Supported criteria are<br/>        "gini" for the Gini impurity and "entropy" for the information gain.<br/>        Note: this parameter is tree-specific.<br/><br/>    max_depth : int, default=None<br/>        The maximum depth of the tree. If None, then nodes are expanded until<br/>        all leaves are pure or until all leaves contain less than<br/>        min_samples_split samples.<br/><br/>    min_samples_split : int or float, default=2<br/>        The minimum number of samples required to split an internal node:<br/><br/>        - If int, then consider `min_samples_split` as the minimum number.<br/>        - If float, then `min_samples_split` is a fraction and<br/>          `ceil(min_samples_split * n_samples)` are the minimum<br/>          number of samples for each split.<br/><br/>        .. versionchanged:: 0.18<br/>           Added float values for fractions.<br/><br/>    min_samples_leaf : int or float, default=1<br/>        The minimum number of samples required to be at a leaf node.<br/>        A split point at any depth will only be considered if it leaves at<br/>        least ``min_samples_leaf`` training samples in each of the left and<br/>        right branches.  This may have the effect of smoothing the model,<br/>        especially in regression.<br/><br/>        - If int, then consider `min_samples_leaf` as the minimum number.<br/>        - If float, then `min_samples_leaf` is a fraction and<br/>          `ceil(min_samples_leaf * n_samples)` are the minimum<br/>          number of samples for each node.<br/><br/>        .. versionchanged:: 0.18<br/>           Added float values for fractions.<br/><br/>    min_weight_fraction_leaf : float, default=0.0<br/>        The minimum weighted fraction of the sum total of weights (of all<br/>        the input samples) required to be at a leaf node. Samples have<br/>        equal weight when sample_weight is not provided.<br/><br/>    max_features : {"auto", "sqrt", "log2"}, int or float, default="auto"<br/>        The number of features to consider when looking for the best split:<br/><br/>        - If int, then consider `max_features` features at each split.<br/>        - If float, then `max_features` is a fraction and<br/>          `round(max_features * n_features)` features are considered at each<br/>          split.<br/>        - If "auto", then `max_features=sqrt(n_features)`.<br/>        - If "sqrt", then `max_features=sqrt(n_features)` (same as "auto").<br/>        - If "log2", then `max_features=log2(n_features)`.<br/>        - If None, then `max_features=n_features`.<br/><br/>        Note: the search for a split does not stop until at least one<br/>        valid partition of the node samples is found, even if it requires to<br/>        effectively inspect more than ``max_features`` features.<br/><br/>    max_leaf_nodes : int, default=None<br/>        Grow trees with ``max_leaf_nodes`` in best-first fashion.<br/>        Best nodes are defined as relative reduction in impurity.<br/>        If None then unlimited number of leaf nodes.<br/><br/>    ...
# **Reweighing:**<details>Reweighing is a preprocessing technique that Weights the examples in each<br/>    (group, label) combination differently to ensure fairness before<br/>    classification [4]_.<br/><br/>    References:<br/>        .. [4] F. Kamiran and T. Calders,  "Data Preprocessing Techniques for<br/>           Classification without Discrimination," Knowledge and Information<br/>           Systems, 2012.<br/>    </details>
# **PrejudiceRemover:**<details>Prejudice remover is an in-processing technique that adds a<br/>    discrimination-aware regularization term to the learning objective [6]_.<br/><br/>    References:<br/>        .. [6] T. Kamishima, S. Akaho, H. Asoh, and J. Sakuma, "Fairness-Aware<br/>           Classifier with Prejudice Remover Regularizer," Joint European<br/>           Conference on Machine Learning and Knowledge Discovery in Databases,<br/>           2012.<br/><br/>    </details>
# <style type="text/css">
# #T_c9f0a_row0_col3, #T_c9f0a_row0_col5, #T_c9f0a_row0_col6, #T_c9f0a_row0_col8, #T_c9f0a_row0_col9, #T_c9f0a_row0_col10, #T_c9f0a_row1_col4, #T_c9f0a_row1_col5, #T_c9f0a_row1_col7, #T_c9f0a_row1_col8, #T_c9f0a_row5_col9 {
#   background-color: #ffffff;
# }
# #T_c9f0a_row0_col4, #T_c9f0a_row0_col7 {
#   background-color: #ffff2e;
# }
# #T_c9f0a_row1_col3 {
#   background-color: #06ff00;
# }
# #T_c9f0a_row1_col6 {
#   background-color: #ffffd4;
# }
# #T_c9f0a_row1_col9 {
#   background-color: #fffff4;
# }
# #T_c9f0a_row1_col10, #T_c9f0a_row2_col3, #T_c9f0a_row3_col4, #T_c9f0a_row3_col6, #T_c9f0a_row3_col7 {
#   font-weight: bold;
#   background-color: #00ff00;
# }
# #T_c9f0a_row2_col4, #T_c9f0a_row2_col7 {
#   background-color: #ffff83;
# }
# #T_c9f0a_row2_col5 {
#   background-color: #ffff82;
# }
# #T_c9f0a_row2_col6 {
#   background-color: #ffff39;
# }
# #T_c9f0a_row2_col8 {
#   background-color: #ffffb4;
# }
# #T_c9f0a_row2_col9 {
#   background-color: #ffffe6;
# }
# #T_c9f0a_row2_col10, #T_c9f0a_row3_col10, #T_c9f0a_row4_col10, #T_c9f0a_row5_col10 {
#   background-color: #00ff00;
# }
# #T_c9f0a_row3_col3 {
#   background-color: #08ff00;
# }
# #T_c9f0a_row3_col5 {
#   background-color: #a3ff00;
# }
# #T_c9f0a_row3_col8 {
#   background-color: #ffff77;
# }
# #T_c9f0a_row3_col9 {
#   background-color: #fffffe;
# }
# #T_c9f0a_row4_col3 {
#   background-color: #03ff00;
# }
# #T_c9f0a_row4_col4, #T_c9f0a_row4_col7 {
#   background-color: #ffff1e;
# }
# #T_c9f0a_row4_col5 {
#   background-color: #d7ff00;
# }
# #T_c9f0a_row4_col6 {
#   background-color: #c2ff00;
# }
# #T_c9f0a_row4_col8 {
#   font-weight: bold;
#   background-color: #8bff00;
# }
# #T_c9f0a_row4_col9 {
#   font-weight: bold;
#   background-color: #ffffd7;
# }
# #T_c9f0a_row5_col3 {
#   background-color: #09ff00;
# }
# #T_c9f0a_row5_col4, #T_c9f0a_row5_col7 {
#   background-color: #ffff13;
# }
# #T_c9f0a_row5_col5 {
#   font-weight: bold;
#   background-color: #7cff00;
# }
# #T_c9f0a_row5_col6 {
#   background-color: #ffff46;
# }
# #T_c9f0a_row5_col8 {
#   background-color: #8cff00;
# }
# </style>
# <table id="T_c9f0a">
#   <caption>Worst = White, Best = Green, Mid = Yellow</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c9f0a_level0_col0" class="col_heading level0 col0" >Mitigation</th>
#       <th id="T_c9f0a_level0_col1" class="col_heading level0 col1" >Dataset</th>
#       <th id="T_c9f0a_level0_col2" class="col_heading level0 col2" >Classifier</th>
#       <th id="T_c9f0a_level0_col3" class="col_heading level0 col3" >balanced_accuracy</th>
#       <th id="T_c9f0a_level0_col4" class="col_heading level0 col4" >mean_difference</th>
#       <th id="T_c9f0a_level0_col5" class="col_heading level0 col5" >average_odds_difference</th>
#       <th id="T_c9f0a_level0_col6" class="col_heading level0 col6" >disparate_impact</th>
#       <th id="T_c9f0a_level0_col7" class="col_heading level0 col7" >statistical_parity_difference</th>
#       <th id="T_c9f0a_level0_col8" class="col_heading level0 col8" >equal_opportunity_difference</th>
#       <th id="T_c9f0a_level0_col9" class="col_heading level0 col9" >theil_index</th>
#       <th id="T_c9f0a_level0_col10" class="col_heading level0 col10" >accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c9f0a_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_c9f0a_row0_col0" class="data row0 col0" >Original</td>
#       <td id="T_c9f0a_row0_col1" class="data row0 col1" >Panel19-Panel19(5.0:2.0:3.0)</td>
#       <td id="T_c9f0a_row0_col2" class="data row0 col2" ></td>
#       <td id="T_c9f0a_row0_col3" class="data row0 col3" >None</td>
#       <td id="T_c9f0a_row0_col4" class="data row0 col4" >-0.153251</td>
#       <td id="T_c9f0a_row0_col5" class="data row0 col5" >None</td>
#       <td id="T_c9f0a_row0_col6" class="data row0 col6" >0.455302</td>
#       <td id="T_c9f0a_row0_col7" class="data row0 col7" >-0.153251</td>
#       <td id="T_c9f0a_row0_col8" class="data row0 col8" >None</td>
#       <td id="T_c9f0a_row0_col9" class="data row0 col9" >None</td>
#       <td id="T_c9f0a_row0_col10" class="data row0 col10" >None</td>
#     </tr>
#     <tr>
#       <th id="T_c9f0a_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_c9f0a_row1_col0" class="data row1 col0" >Original</td>
#       <td id="T_c9f0a_row1_col1" class="data row1 col1" >Panel19-Panel19(5.0:2.0:3.0)</td>
#       <td id="T_c9f0a_row1_col2" class="data row1 col2" >LogisticRegression
# solver='liblinear', random_state=1</td>
#       <td id="T_c9f0a_row1_col3" class="data row1 col3" >0.755588</td>
#       <td id="T_c9f0a_row1_col4" class="data row1 col4" >-0.218486</td>
#       <td id="T_c9f0a_row1_col5" class="data row1 col5" >-0.128144</td>
#       <td id="T_c9f0a_row1_col6" class="data row1 col6" >0.485587</td>
#       <td id="T_c9f0a_row1_col7" class="data row1 col7" >-0.218486</td>
#       <td id="T_c9f0a_row1_col8" class="data row1 col8" >-0.102933</td>
#       <td id="T_c9f0a_row1_col9" class="data row1 col9" >0.093337</td>
#       <td id="T_c9f0a_row1_col10" class="data row1 col10" >0.778879</td>
#     </tr>
#     <tr>
#       <th id="T_c9f0a_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_c9f0a_row2_col0" class="data row2 col0" >Original</td>
#       <td id="T_c9f0a_row2_col1" class="data row2 col1" >Panel19-Panel19(5.0:2.0:3.0)</td>
#       <td id="T_c9f0a_row2_col2" class="data row2 col2" >RandomForestClassifier
# n_estimators=500, min_samples_leaf=25</td>
#       <td id="T_c9f0a_row2_col3" class="data row2 col3" >0.763145</td>
#       <td id="T_c9f0a_row2_col4" class="data row2 col4" >-0.179614</td>
#       <td id="T_c9f0a_row2_col5" class="data row2 col5" >-0.096496</td>
#       <td id="T_c9f0a_row2_col6" class="data row2 col6" >0.592243</td>
#       <td id="T_c9f0a_row2_col7" class="data row2 col7" >-0.179614</td>
#       <td id="T_c9f0a_row2_col8" class="data row2 col8" >-0.087763</td>
#       <td id="T_c9f0a_row2_col9" class="data row2 col9" >0.090628</td>
#       <td id="T_c9f0a_row2_col10" class="data row2 col10" >0.778879</td>
#     </tr>
#     <tr>
#       <th id="T_c9f0a_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_c9f0a_row3_col0" class="data row3 col0" >Reweighing</td>
#       <td id="T_c9f0a_row3_col1" class="data row3 col1" >Panel19-Panel19(5.0:2.0:3.0)</td>
#       <td id="T_c9f0a_row3_col2" class="data row3 col2" >LogisticRegression
# solver='liblinear', random_state=1</td>
#       <td id="T_c9f0a_row3_col3" class="data row3 col3" >0.751927</td>
#       <td id="T_c9f0a_row3_col4" class="data row3 col4" >-0.059741</td>
#       <td id="T_c9f0a_row3_col5" class="data row3 col5" >0.040907</td>
#       <td id="T_c9f0a_row3_col6" class="data row3 col6" >0.806923</td>
#       <td id="T_c9f0a_row3_col7" class="data row3 col7" >-0.059741</td>
#       <td id="T_c9f0a_row3_col8" class="data row3 col8" >0.075360</td>
#       <td id="T_c9f0a_row3_col9" class="data row3 col9" >0.095164</td>
#       <td id="T_c9f0a_row3_col10" class="data row3 col10" >0.778879</td>
#     </tr>
#     <tr>
#       <th id="T_c9f0a_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_c9f0a_row4_col0" class="data row4 col0" >Reweighing</td>
#       <td id="T_c9f0a_row4_col1" class="data row4 col1" >Panel19-Panel19(5.0:2.0:3.0)</td>
#       <td id="T_c9f0a_row4_col2" class="data row4 col2" >RandomForestClassifier
# n_estimators=500, min_samples_leaf=25</td>
#       <td id="T_c9f0a_row4_col3" class="data row4 col3" >0.759209</td>
#       <td id="T_c9f0a_row4_col4" class="data row4 col4" >-0.148346</td>
#       <td id="T_c9f0a_row4_col5" class="data row4 col5" >-0.053945</td>
#       <td id="T_c9f0a_row4_col6" class="data row4 col6" >0.673231</td>
#       <td id="T_c9f0a_row4_col7" class="data row4 col7" >-0.148346</td>
#       <td id="T_c9f0a_row4_col8" class="data row4 col8" >-0.027898</td>
#       <td id="T_c9f0a_row4_col9" class="data row4 col9" >0.087819</td>
#       <td id="T_c9f0a_row4_col10" class="data row4 col10" >0.778879</td>
#     </tr>
#     <tr>
#       <th id="T_c9f0a_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_c9f0a_row5_col0" class="data row5 col0" >PrejudiceRemover
# sensitive_attr='RACE', eta=25.0</td>
#       <td id="T_c9f

# %%
if get_ipython() is not None:
    get_ipython().magic("%matplotlib inline")

# %%
bm.display_barchart()

# %% [markdown]
# ## [2.](#Contents) Bias Mitigation: Model Deployment

# %%
np.random.seed(0)
bm = fairml.add_bias_mitigation(BiasMitigation())
bm.name = "Model Deployment"

# %%
print("")
print("========================")
print("Bias Mitigation: Model Deployment")
print("------------------------")
# Out:
# ========================
# Bias Mitigation: Model Deployment
# ------------------------

# %% [markdown]
# ### [2.1.](#Contents) Dataset Panel19-Panel19

# %%
print("")
print("Dataset: Panel19-Panel19")
print("-------------")
# Out:
# Dataset: Panel19-Panel19
# -------------

# %% [markdown]
# #### [2.1.1.](#Contents) Original Dataset

# %%
bm.predicted_attribute = ''
bm.protected_attributes = ['RACE']
bm.features_to_keep = []
bm.favorable_class = 1
bm.privileged_class = 1
bm.unprivileged_class = 0
bm.dropped_attributes = []
bm.na_values = []
bm.training_size = 5.0    
bm.test_size = 2.0
bm.validation_size = 3.0
bm.total_size = bm.training_size + bm.test_size + bm.validation_size
bm.categorical_features = []
bm.default_mappings = None

# %% [markdown]
# Load dataset

# %%
bm.resource = "" 
bm.dataset_original = MEPSDataset19()

# %%
bm.dataset_original_train, bm.dataset_original_valid, bm.dataset_original_test = bm.dataset_original.split([bm.training_size/bm.total_size, (bm.training_size + bm.validation_size)/bm.total_size], shuffle=True)

# %%
bm.privileged_groups = [{bm.protected_attributes[0] : bm.privileged_class}]
bm.unprivileged_groups = [{bm.protected_attributes[0] : bm.unprivileged_class}]

# %%
bm.init_new_result("Original", "", "Panel19-Panel19", "", "")
bm.measure_bias("balanced_accuracy", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("mean_difference", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("average_odds_difference", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("disparate_impact", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("statistical_parity_difference", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("equal_opportunity_difference", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("theil_index", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("accuracy", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
# Out:
# **Metric:** Mean Difference<br/>**Message:** Mean difference (mean label value on unprivileged instances - mean label value on privileged instances): -0.15325088755766275<br/>**NumPositivesUnprivileged:** 1417292.7295189998<br/>**NumInstancesUnprivileged:** 11063999.162326<br/>**NumPositivesPrivileged:** 4807667.433267<br/>**NumInstancesPrivileged:** 17087829.603329003<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:** The ideal value of this metric is 0.0<br/>
# **Metric:** Disparate Impact<br/>**Message:** Disparate impact (probability of favorable outcome for unprivileged instances / probability of favorable outcome for privileged instances): 0.4553023707455683<br/>**NumPositivePredictionsUnprivileged:** 1417292.7295189998<br/>**NumUnprivileged:** 11063999.162326<br/>**NumPositivePredictionsPrivileged:** 4807667.433267<br/>**NumPrivileged:** 17087829.603329003<br/>**Description:** Computed as the ratio of rate of favorable outcome for the unprivileged group to that of the privileged group.<br/>**Ideal:** The ideal value of this metric is 1.0 A value < 1 implies higher benefit for the privileged group and a value >1 implies a higher benefit for the unprivileged group.<br/>
# **Metric:** Statistical Parity Difference<br/>**Message:** Statistical parity difference (probability of favorable outcome for unprivileged instances - probability of favorable outcome for privileged instances): -0.15325088755766275<br/>**NumPositivesUnprivileged:** 1417292.7295189998<br/>**NumInstancesUnprivileged:** 11063999.162326<br/>**NumPositivesPrivileged:** 4807667.433267<br/>**NumInstancesPrivileged:** 17087829.603329003<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:**  The ideal value of this metric is 0<br/>

# %% [markdown]
# ##### [2.1.1.1.](#Contents) Original Dataset: Classifier LogisticRegression, Parameters: solver='liblinear', random_state=1

# %%
print("")
print("Original Dataset: Classifier LogisticRegression, Parameters: solver='liblinear', random_state=1")
print("-------------")
# Out:
# Original Dataset: Classifier LogisticRegression, Parameters: solver='liblinear', random_state=1
# -------------

# %% [markdown]
# Train the model from the original train data

# %%
classifier = LogisticRegression(solver='liblinear', random_state=1)
model_original_train = bm.train(bm.dataset_original_train,  classifier, without_weight=False)

# %% [markdown]
# ###### [2.1.1.1.1.](#Contents) Original Dataset: Bias Metrics

# %%
print("Original Bias Metrics")
# Out:
# Original Bias Metrics

# %%
dataset_original_train_pred = bm.dataset_original_train.copy(deepcopy=True)
dataset_original_valid_pred = bm.dataset_original_valid.copy(deepcopy=True)
dataset_original_test_pred = bm.dataset_original_test.copy(deepcopy=True)

# %%
standard_scaler = StandardScaler()
dataset_original_train_pred_features = standard_scaler.fit_transform(bm.dataset_original_train.features)
dataset_original_valid_pred_features = standard_scaler.fit_transform(bm.dataset_original_valid.features)
dataset_original_test_pred_features = standard_scaler.fit_transform(bm.dataset_original_test.features)

# %%
dataset_original_train_pred = bm.create_predicted_dataset(dataset_original_train_pred, model_original_train)
dataset_original_valid_pred = bm.create_predicted_dataset(dataset_original_valid_pred, model_original_train)
dataset_original_test_pred = bm.create_predicted_dataset(dataset_original_test_pred, model_original_train)

# %%
pos_ind = np.where(model_original_train.classes_ == bm.dataset_original_train.favorable_label)[0][0]
dataset_original_train_pred.scores = model_original_train.predict_proba(dataset_original_train_pred_features)[:,pos_ind].reshape(-1,1)
dataset_original_valid_pred.scores = model_original_train.predict_proba(dataset_original_valid_pred_features)[:,pos_ind].reshape(-1,1)
dataset_original_test_pred.scores = model_original_train.predict_proba(dataset_original_test_pred_features)[:,pos_ind].reshape(-1,1)

# %%
bm.init_new_result("Original", "", "Panel19-Panel19", "LogisticRegression", "solver='liblinear', random_state=1")

# %%
bm.measure_bias("balanced_accuracy", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train,  )
bm.measure_bias("mean_difference", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train,  )
bm.measure_bias("average_odds_difference", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train, plot_threshold=True, )
bm.measure_bias("disparate_impact", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train, plot_threshold=True, )
bm.measure_bias("statistical_parity_difference", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train,  )
bm.measure_bias("equal_opportunity_difference", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train,  )
bm.measure_bias("theil_index", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train,  )
bm.measure_bias("accuracy", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups,   )
# Out:
# **Metric:** Balanced Accuracy<br/>**Message:** Balanced Classification accuracy (BACC): 0.7555879079086228<br/>**TruePositiveRateUnprivileged:** 0.0<br/>**TrueNegativeRateUnprivileged:** 1.0<br/>**TruePositiveRatePrivileged:** 0.0<br/>**TrueNegativeRatePrivileged:** 1.0<br/>**Description:** Return the balanced accuracy of the ratios of true positives and true negatives examples in the dataset, :math:`0.5 * (TPR + TNR)`,  optionally conditioned on protected attributes.<br/>**Ideal:**  The ideal value of this metric is 1<br/>
# **Metric:** Mean Difference<br/>**Message:** Mean difference (mean label value on unprivileged instances - mean label value on privileged instances): -0.2184864464691803<br/>**NumPositivesUnprivileged:** 1417292.7295189998<br/>**NumInstancesUnprivileged:** 11063999.162326<br/>**NumPositivesPrivileged:** 4807667.433267<br/>**NumInstancesPrivileged:** 17087829.603329003<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:** The ideal value of this metric is 0.0<br/>
# **Metric:** Average Odds Difference<br/>**Message:** Average odds difference (average of TPR difference and FPR difference, 0 = equality of odds): -0.1281443004246115<br/>**NumFalsePositivesUnprivileged:** 1349994.1687440001<br/>**NumNegativesUnprivileged:** 9646706.432807<br/>**NumTruePositivesUnprivileged:** 931882.3918899999<br/>**NumPositivesUnprivileged:** 1417292.7295189998<br/>**NumFalsePositivesPrivileged:** 3601759.01681<br/>**NumNegativesPrivileged:** 12280162.170062002<br/>**NumTruePositivesPrivileged:** 3655951.849946<br/>**NumPositivesPrivileged:** 4807667.433267<br/>**Description:** Computed as average difference of false positive rate (false positives / negatives) and true positive rate (true positives / positives) between unprivileged and privileged groups.<br/>**Ideal:** The ideal value of this metric is 0.  A value of < 0 implies higher benefit for the privileged group and a value > 0 implies higher benefit for the unprivileged group.<br/>
# invalid value encountered in double_scalars
# **Metric:** Disparate Impact<br/>**Message:** Disparate impact (probability of favorable outcome for unprivileged instances / probability of favorable outcome for privileged instances): 0.4855872276473075<br/>**NumPositivePredictionsUnprivileged:** 2281876.560634<br/>**NumUnprivileged:** 11063999.162326<br/>**NumPositivePredictionsPrivileged:** 7257710.866756<br/>**NumPrivileged:** 17087829.603329003<br/>**Description:** Computed as the ratio of likelihood of favorable outcome for the unprivileged group to that of the privileged group.<br/>**Ideal:** The ideal value of this metric is 1.0<br/>
# **Metric:** Statistical Parity Difference<br/>**Message:** Statistical parity difference (probability of favorable outcome for unprivileged instances - probability of favorable outcome for privileged instances): -0.2184864464691803<br/>**NumPositivesUnprivileged:** 2281876.560634<br/>**NumInstancesUnprivileged:** 11063999.162326<br/>**NumPositivesPrivileged:** 7257710.866756<br/>**NumInstancesPrivileged:** 17087829.603329003<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:**  The ideal value of this metric is 0<br/>
# **Metric:** True Positive Rate Difference<br/>**Message:** True positive rate difference (true positive rate on unprivileged instances - true positive rate on privileged instances): -0.10293315446391094<br/>**NumTruePositivesUnprivileged:** 931882.3918899999<br/>**NumPositivesUnprivileged:** 1417292.7295189998<br/>**NumTruePositivesPrivileged:** 3655951.849946<br/>**NumPositivesPrivileged:** 4807667.433267<br/>**Description:** This metric is computed as the difference of true positive rates between the unprivileged and the privileged groups.  The true positive rate is the ratio of true positives to the total number of actual positives for a given group.<br/>**Ideal:** The ideal value is 0. A value of < 0 implies higher benefit for the privileged group and a value > 0 implies higher benefit for the unprivileged group.<br/>
# **Metric:** Theil Index<br/>**Message:** Theil index (generalized entropy index with alpha = 1): 0.09333677716536079<br/>**Description:** Computed as the generalized entropy of benefit for all individuals in the dataset, with alpha = 1. It measures the inequality in benefit allocation for individuals.<br/>**Ideal:** A value of 0 implies perfect fairness.<br/>
# **Metric:** Accuracy<br/>**Message:** Classification accuracy (ACC): 0.7788790129904314<br/>**NumTruePositives:** 0.0<br/>**NumTrueNegatives:** 21926868.602868997<br/>**NumPositives:** 6224960.1627859995<br/>**NumNegatives:** 21926868.602868997<br/>**Description:** Computed as (true positive count + true negative count)/(positive_count + negative_count).<br/>**Ideal:** The ideal value of this metric is 1.0<br/>

# %% [markdown]
# #### [2.1.2.](#Contents) Mitigate Bias using Reweighing

# %%
print("")
print("Mitigate Bias using Reweighing")
print("-------------")
mitigation_method = bm.create_mitigation_method(Reweighing, )
mitigation_method = mitigation_method.fit(bm.dataset_original_train, )
dataset_mitigated_train = mitigation_method.transform(bm.dataset_original_train)
dataset_mitigated_valid = mitigation_method.transform(bm.dataset_original_valid)
dataset_mitigated_test = bm.dataset_original_test
# Out:
# Mitigate Bias using Reweighing
# -------------

# %% [markdown]
# ##### [2.1.2.1.](#Contents) After-mitigation Dataset: Classifier LogisticRegression, Parameters: solver='liblinear', random_state=1

# %%
print("")
print("After-mitigation Training: LogisticRegression, Parameters: solver='liblinear', random_state=1")
print("-------------")
# Out:
# After-mitigation Training: LogisticRegression, Parameters: solver='liblinear', random_state=1
# -------------

# %% [markdown]
# Train the model from the after-mitigation train data

# %%
classifier = LogisticRegression(solver='liblinear', random_state=1)
model_mitigated_train = bm.train(dataset_mitigated_train,  classifier, without_weight=False)

# %% [markdown]
# ###### [2.1.2.1.1.](#Contents) After-mitigation: Bias Metrics

# %%
print("After-mitigation Metrics")
dataset_mitigated_train_pred = bm.create_predicted_dataset(dataset_mitigated_train, model_mitigated_train)
dataset_mitigated_valid_pred = bm.create_predicted_dataset(dataset_mitigated_valid, model_mitigated_train)
dataset_mitigated_test_pred = bm.create_predicted_dataset(dataset_mitigated_test, model_mitigated_train)
# Out:
# After-mitigation Metrics

# %%
bm.init_new_result("Reweighing", "", "Panel19-Panel19", "LogisticRegression", "solver='liblinear', random_state=1")

# %%
bm.measure_bias("balanced_accuracy", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("mean_difference", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("average_odds_difference", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train, plot_threshold=True, )
bm.measure_bias("disparate_impact", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train, plot_threshold=True, )
bm.measure_bias("statistical_parity_difference", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("equal_opportunity_difference", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("theil_index", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("accuracy", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups,   )
# Out:
# **Metric:** Balanced Accuracy<br/>**Message:** Balanced Classification accuracy (BACC): 0.7519272229056848<br/>**TruePositiveRateUnprivileged:** 0.0<br/>**TrueNegativeRateUnprivileged:** 1.0<br/>**TruePositiveRatePrivileged:** 0.0<br/>**TrueNegativeRatePrivileged:** 1.0<br/>**Description:** Return the balanced accuracy of the ratios of true positives and true negatives examples in the dataset, :math:`0.5 * (TPR + TNR)`,  optionally conditioned on protected attributes.<br/>**Ideal:**  The ideal value of this metric is 1<br/>
# **Metric:** Mean Difference<br/>**Message:** Mean difference (mean label value on unprivileged instances - mean label value on privileged instances): -0.05974060268016351<br/>**NumPositivesUnprivileged:** 1417292.7295189998<br/>**NumInstancesUnprivileged:** 11063999.162326<br/>**NumPositivesPrivileged:** 4807667.433267<br/>**NumInstancesPrivileged:** 17087829.603329003<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:** The ideal value of this metric is 0.0<br/>
# **Metric:** Average Odds Difference<br/>**Message:** Average odds difference (average of TPR difference and FPR difference, 0 = equality of odds): 0.04090712529127909<br/>**NumFalsePositivesUnprivileged:** 1718425.0672229999<br/>**NumNegativesUnprivileged:** 9646706.432807<br/>**NumTruePositivesUnprivileged:** 1043945.7571030001<br/>**NumPositivesUnprivileged:** 1417292.7295189998<br/>**NumFalsePositivesPrivileged:** 2108275.163295<br/>**NumNegativesPrivileged:** 12280162.170062002<br/>**NumTruePositivesPrivileged:** 3178914.7077629995<br/>**NumPositivesPrivileged:** 4807667.433267<br/>**Description:** Computed as average difference of false positive rate (false positives / negatives) and true positive rate (true positives / positives) between unprivileged and privileged groups.<br/>**Ideal:** The ideal value of this metric is 0.  A value of < 0 implies higher benefit for the privileged group and a value > 0 implies higher benefit for the unprivileged group.<br/>
# divide by zero encountered in double_scalars
# invalid value encountered in double_scalars
# **Metric:** Disparate Impact<br/>**Message:** Disparate impact (probability of favorable outcome for unprivileged instances / probability of favorable outcome for privileged instances): 0.8069225308917196<br/>**NumPositivePredictionsUnprivileged:** 2762370.824326<br/>**NumUnprivileged:** 11063999.162326<br/>**NumPositivePredictionsPrivileged:** 5287189.871058<br/>**NumPrivileged:** 17087829.603329003<br/>**Description:** Computed as the ratio of likelihood of favorable outcome for the unprivileged group to that of the privileged group.<br/>**Ideal:** The ideal value of this metric is 1.0<br/>
# **Metric:** Statistical Parity Difference<br/>**Message:** Statistical parity difference (probability of favorable outcome for unprivileged instances - probability of favorable outcome for privileged instances): -0.05974060268016351<br/>**NumPositivesUnprivileged:** 2762370.824326<br/>**NumInstancesUnprivileged:** 11063999.162326<br/>**NumPositivesPrivileged:** 5287189.871058<br/>**NumInstancesPrivileged:** 17087829.603329003<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:**  The ideal value of this metric is 0<br/>
# **Metric:** True Positive Rate Difference<br/>**Message:** True positive rate difference (true positive rate on unprivileged instances - true positive rate on privileged instances): 0.07535969386841945<br/>**NumTruePositivesUnprivileged:** 1043945.7571030001<br/>**NumPositivesUnprivileged:** 1417292.7295189998<br/>**NumTruePositivesPrivileged:** 3178914.7077629995<br/>**NumPositivesPrivileged:** 4807667.433267<br/>**Description:** This metric is computed as the difference of true positive rates between the unprivileged and the privileged groups.  The true positive rate is the ratio of true positives to the total number of actual positives for a given group.<br/>**Ideal:** The ideal value is 0. A value of < 0 implies higher benefit for the privileged group and a value > 0 implies higher benefit for the unprivileged group.<br/>
# **Metric:** Theil Index<br/>**Message:** Theil index (generalized entropy index with alpha = 1): 0.09516435065103866<br/>**Description:** Computed as the generalized entropy of benefit for all individuals in the dataset, with alpha = 1. It measures the inequality in benefit allocation for individuals.<br/>**Ideal:** A value of 0 implies perfect fairness.<br/>
# **Metric:** Accuracy<br/>**Message:** Classification accuracy (ACC): 0.7788790129904314<br/>**NumTruePositives:** 0.0<br/>**NumTrueNegatives:** 21926868.602868997<br/>**NumPositives:** 6224960.1627859995<br/>**NumNegatives:** 21926868.602868997<br/>**Description:** Computed as (true positive count + true negative count)/(positive_count + negative_count).<br/>**Ideal:** The ideal value of this metric is 1.0<br/>

# %% [markdown]
# ### [2.2.](#Contents) Dataset Panel19-Panel20

# %%
print("")
print("Dataset: Panel19-Panel20")
print("-------------")
# Out:
# Dataset: Panel19-Panel20
# -------------

# %% [markdown]
# #### [2.2.1.](#Contents) Original Dataset

# %%
bm.predicted_attribute = ''
bm.protected_attributes = ['RACE']
bm.features_to_keep = []
bm.favorable_class = 1
bm.privileged_class = 1
bm.unprivileged_class = 0
bm.dropped_attributes = []
bm.na_values = []
bm.training_size = 5.0    
bm.test_size = 2.0
bm.validation_size = 3.0
bm.total_size = bm.training_size + bm.test_size + bm.validation_size
bm.categorical_features = []
bm.default_mappings = None

# %% [markdown]
# Load dataset

# %%
bm.resource = "" 
bm.dataset_original = MEPSDataset19()

# %%
bm.dataset_original_train, bm.dataset_original_valid, bm.dataset_original_test = bm.dataset_original.split([bm.training_size/bm.total_size, (bm.training_size + bm.validation_size)/bm.total_size], shuffle=True)

# %%
bm.test_dataset_module = MEPSDataset20()
bm.test_dataset_module = bm.dataset_original_train.align_datasets(bm.test_dataset_module)
_ , _ , bm.dataset_original_test = bm.test_dataset_module.split([bm.training_size/bm.total_size, (bm.training_size + bm.validation_size)/bm.total_size], shuffle=True)

# %%
bm.privileged_groups = [{bm.protected_attributes[0] : bm.privileged_class}]
bm.unprivileged_groups = [{bm.protected_attributes[0] : bm.unprivileged_class}]

# %%
bm.init_new_result("Original", "", "Panel19-Panel20", "", "")
bm.measure_bias("balanced_accuracy", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("mean_difference", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("average_odds_difference", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("disparate_impact", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("statistical_parity_difference", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("equal_opportunity_difference", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("theil_index", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("accuracy", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
# Out:
# **Metric:** Mean Difference<br/>**Message:** Mean difference (mean label value on unprivileged instances - mean label value on privileged instances): -0.10832159983089625<br/>**NumPositivesUnprivileged:** 1563891.888131<br/>**NumInstancesUnprivileged:** 12559825.290665999<br/>**NumPositivesPrivileged:** 4709328.691608<br/>**NumInstancesPrivileged:** 20225859.050555997<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:** The ideal value of this metric is 0.0<br/>
# **Metric:** Disparate Impact<br/>**Message:** Disparate impact (probability of favorable outcome for unprivileged instances / probability of favorable outcome for privileged instances): 0.5347750064219119<br/>**NumPositivePredictionsUnprivileged:** 1563891.888131<br/>**NumUnprivileged:** 12559825.290665999<br/>**NumPositivePredictionsPrivileged:** 4709328.691608<br/>**NumPrivileged:** 20225859.050555997<br/>**Description:** Computed as the ratio of rate of favorable outcome for the unprivileged group to that of the privileged group.<br/>**Ideal:** The ideal value of this metric is 1.0 A value < 1 implies higher benefit for the privileged group and a value >1 implies a higher benefit for the unprivileged group.<br/>
# **Metric:** Statistical Parity Difference<br/>**Message:** Statistical parity difference (probability of favorable outcome for unprivileged instances - probability of favorable outcome for privileged instances): -0.10832159983089625<br/>**NumPositivesUnprivileged:** 1563891.888131<br/>**NumInstancesUnprivileged:** 12559825.290665999<br/>**NumPositivesPrivileged:** 4709328.691608<br/>**NumInstancesPrivileged:** 20225859.050555997<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:**  The ideal value of this metric is 0<br/>

# %% [markdown]
# ##### [2.2.1.1.](#Contents) Original Dataset: Classifier LogisticRegression, Parameters: solver='liblinear', random_state=1

# %%
print("")
print("Original Dataset: Classifier LogisticRegression, Parameters: solver='liblinear', random_state=1")
print("-------------")
# Out:
# Original Dataset: Classifier LogisticRegression, Parameters: solver='liblinear', random_state=1
# -------------

# %% [markdown]
# Train the model from the original train data

# %%
classifier = LogisticRegression(solver='liblinear', random_state=1)
model_original_train = bm.train(bm.dataset_original_train,  classifier, without_weight=False)

# %% [markdown]
# ###### [2.2.1.1.1.](#Contents) Original Dataset: Bias Metrics

# %%
print("Original Bias Metrics")
# Out:
# Original Bias Metrics

# %%
dataset_original_train_pred = bm.dataset_original_train.copy(deepcopy=True)
dataset_original_valid_pred = bm.dataset_original_valid.copy(deepcopy=True)
dataset_original_test_pred = bm.dataset_original_test.copy(deepcopy=True)

# %%
standard_scaler = StandardScaler()
dataset_original_train_pred_features = standard_scaler.fit_transform(bm.dataset_original_train.features)
dataset_original_valid_pred_features = standard_scaler.fit_transform(bm.dataset_original_valid.features)
dataset_original_test_pred_features = standard_scaler.fit_transform(bm.dataset_original_test.features)

# %%
dataset_original_train_pred = bm.create_predicted_dataset(dataset_original_train_pred, model_original_train)
dataset_original_valid_pred = bm.create_predicted_dataset(dataset_original_valid_pred, model_original_train)
dataset_original_test_pred = bm.create_predicted_dataset(dataset_original_test_pred, model_original_train)

# %%
pos_ind = np.where(model_original_train.classes_ == bm.dataset_original_train.favorable_label)[0][0]
dataset_original_train_pred.scores = model_original_train.predict_proba(dataset_original_train_pred_features)[:,pos_ind].reshape(-1,1)
dataset_original_valid_pred.scores = model_original_train.predict_proba(dataset_original_valid_pred_features)[:,pos_ind].reshape(-1,1)
dataset_original_test_pred.scores = model_original_train.predict_proba(dataset_original_test_pred_features)[:,pos_ind].reshape(-1,1)

# %%
bm.init_new_result("Original", "", "Panel19-Panel20", "LogisticRegression", "solver='liblinear', random_state=1")

# %%
bm.measure_bias("balanced_accuracy", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train,  )
bm.measure_bias("mean_difference", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train,  )
bm.measure_bias("average_odds_difference", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train, plot_threshold=True, )
bm.measure_bias("disparate_impact", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train, plot_threshold=True, )
bm.measure_bias("statistical_parity_difference", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train,  )
bm.measure_bias("equal_opportunity_difference", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train,  )
bm.measure_bias("theil_index", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train,  )
bm.measure_bias("accuracy", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups,   )
# Out:
# **Metric:** Balanced Accuracy<br/>**Message:** Balanced Classification accuracy (BACC): 0.7424588151523519<br/>**TruePositiveRateUnprivileged:** 0.0<br/>**TrueNegativeRateUnprivileged:** 1.0<br/>**TruePositiveRatePrivileged:** 0.0<br/>**TrueNegativeRatePrivileged:** 1.0<br/>**Description:** Return the balanced accuracy of the ratios of true positives and true negatives examples in the dataset, :math:`0.5 * (TPR + TNR)`,  optionally conditioned on protected attributes.<br/>**Ideal:**  The ideal value of this metric is 1<br/>
# **Metric:** Mean Difference<br/>**Message:** Mean difference (mean label value on unprivileged instances - mean label value on privileged instances): -0.21641096335236668<br/>**NumPositivesUnprivileged:** 1563891.888131<br/>**NumInstancesUnprivileged:** 12559825.290665999<br/>**NumPositivesPrivileged:** 4709328.691608<br/>**NumInstancesPrivileged:** 20225859.050555997<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:** The ideal value of this metric is 0.0<br/>
# **Metric:** Average Odds Difference<br/>**Message:** Average odds difference (average of TPR difference and FPR difference, 0 = equality of odds): -0.15418022539163695<br/>**NumFalsePositivesUnprivileged:** 1455857.219458<br/>**NumNegativesUnprivileged:** 10995933.402534999<br/>**NumTruePositivesUnprivileged:** 963882.592748<br/>**NumPositivesUnprivileged:** 1563891.888131<br/>**NumFalsePositivesPrivileged:** 4731601.364444<br/>**NumNegativesPrivileged:** 15516530.358948<br/>**NumTruePositivesPrivileged:** 3542152.102383<br/>**NumPositivesPrivileged:** 4709328.691608<br/>**Description:** Computed as average difference of false positive rate (false positives / negatives) and true positive rate (true positives / positives) between unprivileged and privileged groups.<br/>**Ideal:** The ideal value of this metric is 0.  A value of < 0 implies higher benefit for the privileged group and a value > 0 implies higher benefit for the unprivileged group.<br/>
# invalid value encountered in double_scalars
# **Metric:** Disparate Impact<br/>**Message:** Disparate impact (probability of favorable outcome for unprivileged instances / probability of favorable outcome for privileged instances): 0.4709659093288608<br/>**NumPositivePredictionsUnprivileged:** 2419739.812206<br/>**NumUnprivileged:** 12559825.290665999<br/>**NumPositivePredictionsPrivileged:** 8273753.466827<br/>**NumPrivileged:** 20225859.050555997<br/>**Description:** Computed as the ratio of likelihood of favorable outcome for the unprivileged group to that of the privileged group.<br/>**Ideal:** The ideal value of this metric is 1.0<br/>
# **Metric:** Statistical Parity Difference<br/>**Message:** Statistical parity difference (probability of favorable outcome for unprivileged instances - probability of favorable outcome for privileged instances): -0.21641096335236668<br/>**NumPositivesUnprivileged:** 2419739.812206<br/>**NumInstancesUnprivileged:** 12559825.290665999<br/>**NumPositivesPrivileged:** 8273753.466827<br/>**NumInstancesPrivileged:** 20225859.050555997<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:**  The ideal value of this metric is 0<br/>
# **Metric:** True Positive Rate Difference<br/>**Message:** True positive rate difference (true positive rate on unprivileged instances - true positive rate on privileged instances): -0.1358206600094457<br/>**NumTruePositivesUnprivileged:** 963882.592748<br/>**NumPositivesUnprivileged:** 1563891.888131<br/>**NumTruePositivesPrivileged:** 3542152.102383<br/>**NumPositivesPrivileged:** 4709328.691608<br/>**Description:** This metric is computed as the difference of true positive rates between the unprivileged and the privileged groups.  The true positive rate is the ratio of true positives to the total number of actual positives for a given group.<br/>**Ideal:** The ideal value is 0. A value of < 0 implies higher benefit for the privileged group and a value > 0 implies higher benefit for the unprivileged group.<br/>
# **Metric:** Theil Index<br/>**Message:** Theil index (generalized entropy index with alpha = 1): 0.09808249207299831<br/>**Description:** Computed as the generalized entropy of benefit for all individuals in the dataset, with alpha = 1. It measures the inequality in benefit allocation for individuals.<br/>**Ideal:** A value of 0 implies perfect fairness.<br/>
# **Metric:** Accuracy<br/>**Message:** Classification accuracy (ACC): 0.808659763985723<br/>**NumTruePositives:** 0.0<br/>**NumTrueNegatives:** 26512463.761483<br/>**NumPositives:** 6273220.579739<br/>**NumNegatives:** 26512463.761483<br/>**Description:** Computed as (true positive count + true negative count)/(positive_count + negative_count).<br/>**Ideal:** The ideal value of this metric is 1.0<br/>

# %% [markdown]
# #### [2.2.2.](#Contents) Mitigate Bias using Reweighing

# %%
print("")
print("Mitigate Bias using Reweighing")
print("-------------")
mitigation_method = bm.create_mitigation_method(Reweighing, )
mitigation_method = mitigation_method.fit(bm.dataset_original_train, )
dataset_mitigated_train = mitigation_method.transform(bm.dataset_original_train)
dataset_mitigated_valid = mitigation_method.transform(bm.dataset_original_valid)
dataset_mitigated_test = bm.dataset_original_test
# Out:
# Mitigate Bias using Reweighing
# -------------

# %% [markdown]
# ##### [2.2.2.1.](#Contents) After-mitigation Dataset: Classifier LogisticRegression, Parameters: solver='liblinear', random_state=1

# %%
print("")
print("After-mitigation Training: LogisticRegression, Parameters: solver='liblinear', random_state=1")
print("-------------")
# Out:
# After-mitigation Training: LogisticRegression, Parameters: solver='liblinear', random_state=1
# -------------

# %% [markdown]
# Train the model from the after-mitigation train data

# %%
classifier = LogisticRegression(solver='liblinear', random_state=1)
model_mitigated_train = bm.train(dataset_mitigated_train,  classifier, without_weight=False)

# %% [markdown]
# ###### [2.2.2.1.1.](#Contents) After-mitigation: Bias Metrics

# %%
print("After-mitigation Metrics")
dataset_mitigated_train_pred = bm.create_predicted_dataset(dataset_mitigated_train, model_mitigated_train)
dataset_mitigated_valid_pred = bm.create_predicted_dataset(dataset_mitigated_valid, model_mitigated_train)
dataset_mitigated_test_pred = bm.create_predicted_dataset(dataset_mitigated_test, model_mitigated_train)
# Out:
# After-mitigation Metrics

# %%
bm.init_new_result("Reweighing", "", "Panel19-Panel20", "LogisticRegression", "solver='liblinear', random_state=1")

# %%
bm.measure_bias("balanced_accuracy", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("mean_difference", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("average_odds_difference", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train, plot_threshold=True, )
bm.measure_bias("disparate_impact", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train, plot_threshold=True, )
bm.measure_bias("statistical_parity_difference", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("equal_opportunity_difference", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("theil_index", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("accuracy", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups,   )
# Out:
# **Metric:** Balanced Accuracy<br/>**Message:** Balanced Classification accuracy (BACC): 0.7385486022238994<br/>**TruePositiveRateUnprivileged:** 0.0<br/>**TrueNegativeRateUnprivileged:** 1.0<br/>**TruePositiveRatePrivileged:** 0.0<br/>**TrueNegativeRatePrivileged:** 1.0<br/>**Description:** Return the balanced accuracy of the ratios of true positives and true negatives examples in the dataset, :math:`0.5 * (TPR + TNR)`,  optionally conditioned on protected attributes.<br/>**Ideal:**  The ideal value of this metric is 1<br/>
# **Metric:** Mean Difference<br/>**Message:** Mean difference (mean label value on unprivileged instances - mean label value on privileged instances): -0.03911042382385216<br/>**NumPositivesUnprivileged:** 1563891.888131<br/>**NumInstancesUnprivileged:** 12559825.290665999<br/>**NumPositivesPrivileged:** 4709328.691608<br/>**NumInstancesPrivileged:** 20225859.050555997<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:** The ideal value of this metric is 0.0<br/>
# **Metric:** Average Odds Difference<br/>**Message:** Average odds difference (average of TPR difference and FPR difference, 0 = equality of odds): 0.04618911732331449<br/>**NumFalsePositivesUnprivileged:** 3307535.3361339998<br/>**NumNegativesUnprivileged:** 10995933.402534999<br/>**NumTruePositivesUnprivileged:** 1329387.561462<br/>**NumPositivesUnprivileged:** 1563891.888131<br/>**NumFalsePositivesPrivileged:** 4699935.68348<br/>**NumNegativesPrivileged:** 15516530.358948<br/>**NumTruePositivesPrivileged:** 3558228.332606<br/>**NumPositivesPrivileged:** 4709328.691608<br/>**Description:** Computed as average difference of false positive rate (false positives / negatives) and true positive rate (true positives / positives) between unprivileged and privileged groups.<br/>**Ideal:** The ideal value of this metric is 0.  A value of < 0 implies higher benefit for the privileged group and a value > 0 implies higher benefit for the unprivileged group.<br/>
# divide by zero encountered in double_scalars
# invalid value encountered in double_scalars
# **Metric:** Disparate Impact<br/>**Message:** Disparate impact (probability of favorable outcome for unprivileged instances / probability of favorable outcome for privileged instances): 0.9042109216857551<br/>**NumPositivePredictionsUnprivileged:** 4636922.897596<br/>**NumUnprivileged:** 12559825.290665999<br/>**NumPositivePredictionsPrivileged:** 8258164.016085999<br/>**NumPrivileged:** 20225859.050555997<br/>**Description:** Computed as the ratio of likelihood of favorable outcome for the unprivileged group to that of the privileged group.<br/>**Ideal:** The ideal value of this metric is 1.0<br/>
# **Metric:** Statistical Parity Difference<br/>**Message:** Statistical parity difference (probability of favorable outcome for unprivileged instances - probability of favorable outcome for privileged instances): -0.03911042382385216<br/>**NumPositivesUnprivileged:** 4636922.897596<br/>**NumInstancesUnprivileged:** 12559825.290665999<br/>**NumPositivesPrivileged:** 8258164.016085999<br/>**NumInstancesPrivileged:** 20225859.050555997<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:**  The ideal value of this metric is 0<br/>
# **Metric:** True Positive Rate Difference<br/>**Message:** True positive rate difference (true positive rate on unprivileged instances - true positive rate on privileged instances): 0.09448062578469096<br/>**NumTruePositivesUnprivileged:** 1329387.561462<br/>**NumPositivesUnprivileged:** 1563891.888131<br/>**NumTruePositivesPrivileged:** 3558228.332606<br/>**NumPositivesPrivileged:** 4709328.691608<br/>**Description:** This metric is computed as the difference of true positive rates between the unprivileged and the privileged groups.  The true positive rate is the ratio of true positives to the total number of actual positives for a given group.<br/>**Ideal:** The ideal value is 0. A value of < 0 implies higher benefit for the privileged group and a value > 0 implies higher benefit for the unprivileged group.<br/>
# **Metric:** Theil Index<br/>**Message:** Theil index (generalized entropy index with alpha = 1): 0.09222331489651855<br/>**Description:** Computed as the generalized entropy of benefit for all individuals in the dataset, with alpha = 1. It measures the inequality in benefit allocation for individuals.<br/>**Ideal:** A value of 0 implies perfect fairness.<br/>
# **Metric:** Accuracy<br/>**Message:** Classification accuracy (ACC): 0.808659763985723<br/>**NumTruePositives:** 0.0<br/>**NumTrueNegatives:** 26512463.761483<br/>**NumPositives:** 6273220.579739<br/>**NumNegatives:** 26512463.761483<br/>**Description:** Computed as (true positive count + true negative count)/(positive_count + negative_count).<br/>**Ideal:** The ideal value of this metric is 1.0<br/>

# %% [markdown]
# ### [2.3.](#Contents) Dataset Panel19-Panel21

# %%
print("")
print("Dataset: Panel19-Panel21")
print("-------------")
# Out:
# Dataset: Panel19-Panel21
# -------------

# %% [markdown]
# #### [2.3.1.](#Contents) Original Dataset

# %%
bm.predicted_attribute = ''
bm.protected_attributes = ['RACE']
bm.features_to_keep = []
bm.favorable_class = 1
bm.privileged_class = 1
bm.unprivileged_class = 0
bm.dropped_attributes = []
bm.na_values = []
bm.training_size = 5.0    
bm.test_size = 2.0
bm.validation_size = 3.0
bm.total_size = bm.training_size + bm.test_size + bm.validation_size
bm.categorical_features = []
bm.default_mappings = None

# %% [markdown]
# Load dataset

# %%
bm.resource = "" 
bm.dataset_original = MEPSDataset19()

# %%
bm.dataset_original_train, bm.dataset_original_valid, bm.dataset_original_test = bm.dataset_original.split([bm.training_size/bm.total_size, (bm.training_size + bm.validation_size)/bm.total_size], shuffle=True)

# %%
bm.test_dataset_module = MEPSDataset21()
bm.test_dataset_module = bm.dataset_original_train.align_datasets(bm.test_dataset_module)
_ , _ , bm.dataset_original_test = bm.test_dataset_module.split([bm.training_size/bm.total_size, (bm.training_size + bm.validation_size)/bm.total_size], shuffle=True)

# %%
bm.privileged_groups = [{bm.protected_attributes[0] : bm.privileged_class}]
bm.unprivileged_groups = [{bm.protected_attributes[0] : bm.unprivileged_class}]

# %%
bm.init_new_result("Original", "", "Panel19-Panel21", "", "")
bm.measure_bias("balanced_accuracy", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("mean_difference", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("average_odds_difference", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("disparate_impact", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("statistical_parity_difference", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("equal_opportunity_difference", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("theil_index", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("accuracy", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
# Out:
# **Metric:** Mean Difference<br/>**Message:** Mean difference (mean label value on unprivileged instances - mean label value on privileged instances): -0.14572701194835258<br/>**NumPositivesUnprivileged:** 1227467.23716<br/>**NumInstancesUnprivileged:** 11638552.790278<br/>**NumPositivesPrivileged:** 4538728.323577999<br/>**NumInstancesPrivileged:** 18068715.665896997<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:** The ideal value of this metric is 0.0<br/>
# **Metric:** Disparate Impact<br/>**Message:** Disparate impact (probability of favorable outcome for unprivileged instances / probability of favorable outcome for privileged instances): 0.4198595386163552<br/>**NumPositivePredictionsUnprivileged:** 1227467.23716<br/>**NumUnprivileged:** 11638552.790278<br/>**NumPositivePredictionsPrivileged:** 4538728.323577999<br/>**NumPrivileged:** 18068715.665896997<br/>**Description:** Computed as the ratio of rate of favorable outcome for the unprivileged group to that of the privileged group.<br/>**Ideal:** The ideal value of this metric is 1.0 A value < 1 implies higher benefit for the privileged group and a value >1 implies a higher benefit for the unprivileged group.<br/>
# **Metric:** Statistical Parity Difference<br/>**Message:** Statistical parity difference (probability of favorable outcome for unprivileged instances - probability of favorable outcome for privileged instances): -0.14572701194835258<br/>**NumPositivesUnprivileged:** 1227467.23716<br/>**NumInstancesUnprivileged:** 11638552.790278<br/>**NumPositivesPrivileged:** 4538728.323577999<br/>**NumInstancesPrivileged:** 18068715.665896997<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:**  The ideal value of this metric is 0<br/>

# %% [markdown]
# ##### [2.3.1.1.](#Contents) Original Dataset: Classifier LogisticRegression, Parameters: solver='liblinear', random_state=1

# %%
print("")
print("Original Dataset: Classifier LogisticRegression, Parameters: solver='liblinear', random_state=1")
print("-------------")
# Out:
# Original Dataset: Classifier LogisticRegression, Parameters: solver='liblinear', random_state=1
# -------------

# %% [markdown]
# Train the model from the original train data

# %%
classifier = LogisticRegression(solver='liblinear', random_state=1)
model_original_train = bm.train(bm.dataset_original_train,  classifier, without_weight=False)

# %% [markdown]
# ###### [2.3.1.1.1.](#Contents) Original Dataset: Bias Metrics

# %%
print("Original Bias Metrics")
# Out:
# Original Bias Metrics

# %%
dataset_original_train_pred = bm.dataset_original_train.copy(deepcopy=True)
dataset_original_valid_pred = bm.dataset_original_valid.copy(deepcopy=True)
dataset_original_test_pred = bm.dataset_original_test.copy(deepcopy=True)

# %%
standard_scaler = StandardScaler()
dataset_original_train_pred_features = standard_scaler.fit_transform(bm.dataset_original_train.features)
dataset_original_valid_pred_features = standard_scaler.fit_transform(bm.dataset_original_valid.features)
dataset_original_test_pred_features = standard_scaler.fit_transform(bm.dataset_original_test.features)

# %%
dataset_original_train_pred = bm.create_predicted_dataset(dataset_original_train_pred, model_original_train)
dataset_original_valid_pred = bm.create_predicted_dataset(dataset_original_valid_pred, model_original_train)
dataset_original_test_pred = bm.create_predicted_dataset(dataset_original_test_pred, model_original_train)

# %%
pos_ind = np.where(model_original_train.classes_ == bm.dataset_original_train.favorable_label)[0][0]
dataset_original_train_pred.scores = model_original_train.predict_proba(dataset_original_train_pred_features)[:,pos_ind].reshape(-1,1)
dataset_original_valid_pred.scores = model_original_train.predict_proba(dataset_original_valid_pred_features)[:,pos_ind].reshape(-1,1)
dataset_original_test_pred.scores = model_original_train.predict_proba(dataset_original_test_pred_features)[:,pos_ind].reshape(-1,1)

# %%
bm.init_new_result("Original", "", "Panel19-Panel21", "LogisticRegression", "solver='liblinear', random_state=1")

# %%
bm.measure_bias("balanced_accuracy", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train,  )
bm.measure_bias("mean_difference", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train,  )
bm.measure_bias("average_odds_difference", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train, plot_threshold=True, )
bm.measure_bias("disparate_impact", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train, plot_threshold=True, )
bm.measure_bias("statistical_parity_difference", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train,  )
bm.measure_bias("equal_opportunity_difference", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train,  )
bm.measure_bias("theil_index", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train,  )
bm.measure_bias("accuracy", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups,   )
# Out:
# **Metric:** Balanced Accuracy<br/>**Message:** Balanced Classification accuracy (BACC): 0.7480075804468029<br/>**TruePositiveRateUnprivileged:** 0.0<br/>**TrueNegativeRateUnprivileged:** 1.0<br/>**TruePositiveRatePrivileged:** 0.0<br/>**TrueNegativeRatePrivileged:** 1.0<br/>**Description:** Return the balanced accuracy of the ratios of true positives and true negatives examples in the dataset, :math:`0.5 * (TPR + TNR)`,  optionally conditioned on protected attributes.<br/>**Ideal:**  The ideal value of this metric is 1<br/>
# **Metric:** Mean Difference<br/>**Message:** Mean difference (mean label value on unprivileged instances - mean label value on privileged instances): -0.2669525174230419<br/>**NumPositivesUnprivileged:** 1227467.23716<br/>**NumInstancesUnprivileged:** 11638552.790278<br/>**NumPositivesPrivileged:** 4538728.323577999<br/>**NumInstancesPrivileged:** 18068715.665896997<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:** The ideal value of this metric is 0.0<br/>
# **Metric:** Average Odds Difference<br/>**Message:** Average odds difference (average of TPR difference and FPR difference, 0 = equality of odds): -0.21264021678132847<br/>**NumFalsePositivesUnprivileged:** 1310351.126577<br/>**NumNegativesUnprivileged:** 10411085.553118<br/>**NumTruePositivesUnprivileged:** 678889.1283870001<br/>**NumPositivesUnprivileged:** 1227467.23716<br/>**NumFalsePositivesPrivileged:** 4363891.340265<br/>**NumNegativesPrivileged:** 13529987.342319<br/>**NumTruePositivesPrivileged:** 3547869.78092<br/>**NumPositivesPrivileged:** 4538728.323577999<br/>**Description:** Computed as average difference of false positive rate (false positives / negatives) and true positive rate (true positives / positives) between unprivileged and privileged groups.<br/>**Ideal:** The ideal value of this metric is 0.  A value of < 0 implies higher benefit for the privileged group and a value > 0 implies higher benefit for the unprivileged group.<br/>
# invalid value encountered in double_scalars
# **Metric:** Disparate Impact<br/>**Message:** Disparate impact (probability of favorable outcome for unprivileged instances / probability of favorable outcome for privileged instances): 0.390339387181863<br/>**NumPositivePredictionsUnprivileged:** 1989240.254964<br/>**NumUnprivileged:** 11638552.790278<br/>**NumPositivePredictionsPrivileged:** 7911761.121185<br/>**NumPrivileged:** 18068715.665896997<br/>**Description:** Computed as the ratio of likelihood of favorable outcome for the unprivileged group to that of the privileged group.<br/>**Ideal:** The ideal value of this metric is 1.0<br/>
# **Metric:** Statistical Parity Difference<br/>**Message:** Statistical parity difference (probability of favorable outcome for unprivileged instances - probability of favorable outcome for privileged instances): -0.2669525174230419<br/>**NumPositivesUnprivileged:** 1989240.254964<br/>**NumInstancesUnprivileged:** 11638552.790278<br/>**NumPositivesPrivileged:** 7911761.121185<br/>**NumInstancesPrivileged:** 18068715.665896997<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:**  The ideal value of this metric is 0<br/>
# **Metric:** True Positive Rate Difference<br/>**Message:** True positive rate difference (true positive rate on unprivileged instances - true positive rate on privileged instances): -0.22860680759600704<br/>**NumTruePositivesUnprivileged:** 678889.1283870001<br/>**NumPositivesUnprivileged:** 1227467.23716<br/>**NumTruePositivesPrivileged:** 3547869.78092<br/>**NumPositivesPrivileged:** 4538728.323577999<br/>**Description:** This metric is computed as the difference of true positive rates between the unprivileged and the privileged groups.  The true positive rate is the ratio of true positives to the total number of actual positives for a given group.<br/>**Ideal:** The ideal value is 0. A value of < 0 implies higher benefit for the privileged group and a value > 0 implies higher benefit for the unprivileged group.<br/>
# **Metric:** Theil Index<br/>**Message:** Theil index (generalized entropy index with alpha = 1): 0.09220086356462934<br/>**Description:** Computed as the generalized entropy of benefit for all individuals in the dataset, with alpha = 1. It measures the inequality in benefit allocation for individuals.<br/>**Ideal:** A value of 0 implies perfect fairness.<br/>
# **Metric:** Accuracy<br/>**Message:** Classification accuracy (ACC): 0.8058995033742516<br/>**NumTruePositives:** 0.0<br/>**NumTrueNegatives:** 23941072.895437002<br/>**NumPositives:** 5766195.560737999<br/>**NumNegatives:** 23941072.895437002<br/>**Description:** Computed as (true positive count + true negative count)/(positive_count + negative_count).<br/>**Ideal:** The ideal value of this metric is 1.0<br/>

# %% [markdown]
# #### [2.3.2.](#Contents) Mitigate Bias using Reweighing

# %%
print("")
print("Mitigate Bias using Reweighing")
print("-------------")
mitigation_method = bm.create_mitigation_method(Reweighing, )
mitigation_method = mitigation_method.fit(bm.dataset_original_train, )
dataset_mitigated_train = mitigation_method.transform(bm.dataset_original_train)
dataset_mitigated_valid = mitigation_method.transform(bm.dataset_original_valid)
dataset_mitigated_test = bm.dataset_original_test
# Out:
# Mitigate Bias using Reweighing
# -------------

# %% [markdown]
# ##### [2.3.2.1.](#Contents) After-mitigation Dataset: Classifier LogisticRegression, Parameters: solver='liblinear', random_state=1

# %%
print("")
print("After-mitigation Training: LogisticRegression, Parameters: solver='liblinear', random_state=1")
print("-------------")
# Out:
# After-mitigation Training: LogisticRegression, Parameters: solver='liblinear', random_state=1
# -------------

# %% [markdown]
# Train the model from the after-mitigation train data

# %%
classifier = LogisticRegression(solver='liblinear', random_state=1)
model_mitigated_train = bm.train(dataset_mitigated_train,  classifier, without_weight=False)

# %% [markdown]
# ###### [2.3.2.1.1.](#Contents) After-mitigation: Bias Metrics

# %%
print("After-mitigation Metrics")
dataset_mitigated_train_pred = bm.create_predicted_dataset(dataset_mitigated_train, model_mitigated_train)
dataset_mitigated_valid_pred = bm.create_predicted_dataset(dataset_mitigated_valid, model_mitigated_train)
dataset_mitigated_test_pred = bm.create_predicted_dataset(dataset_mitigated_test, model_mitigated_train)
# Out:
# After-mitigation Metrics

# %%
bm.init_new_result("Reweighing", "", "Panel19-Panel21", "LogisticRegression", "solver='liblinear', random_state=1")

# %%
bm.measure_bias("balanced_accuracy", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("mean_difference", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("average_odds_difference", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train, plot_threshold=True, )
bm.measure_bias("disparate_impact", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train, plot_threshold=True, )
bm.measure_bias("statistical_parity_difference", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("equal_opportunity_difference", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("theil_index", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("accuracy", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups,   )
# Out:
# **Metric:** Balanced Accuracy<br/>**Message:** Balanced Classification accuracy (BACC): 0.7342184031429903<br/>**TruePositiveRateUnprivileged:** 0.0<br/>**TrueNegativeRateUnprivileged:** 1.0<br/>**TruePositiveRatePrivileged:** 0.0<br/>**TrueNegativeRatePrivileged:** 1.0<br/>**Description:** Return the balanced accuracy of the ratios of true positives and true negatives examples in the dataset, :math:`0.5 * (TPR + TNR)`,  optionally conditioned on protected attributes.<br/>**Ideal:**  The ideal value of this metric is 1<br/>
# **Metric:** Mean Difference<br/>**Message:** Mean difference (mean label value on unprivileged instances - mean label value on privileged instances): -0.09666272571169776<br/>**NumPositivesUnprivileged:** 1227467.23716<br/>**NumInstancesUnprivileged:** 11638552.790278<br/>**NumPositivesPrivileged:** 4538728.323577999<br/>**NumInstancesPrivileged:** 18068715.665896997<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:** The ideal value of this metric is 0.0<br/>
# **Metric:** Average Odds Difference<br/>**Message:** Average odds difference (average of TPR difference and FPR difference, 0 = equality of odds): -0.030440090180438917<br/>**NumFalsePositivesUnprivileged:** 1670823.9909019999<br/>**NumNegativesUnprivileged:** 10411085.553118<br/>**NumTruePositivesUnprivileged:** 761162.0772429999<br/>**NumPositivesUnprivileged:** 1227467.23716<br/>**NumFalsePositivesPrivileged:** 2562637.641572<br/>**NumNegativesPrivileged:** 13529987.342319<br/>**NumTruePositivesPrivileged:** 2959563.295099<br/>**NumPositivesPrivileged:** 4538728.323577999<br/>**Description:** Computed as average difference of false positive rate (false positives / negatives) and true positive rate (true positives / positives) between unprivileged and privileged groups.<br/>**Ideal:** The ideal value of this metric is 0.  A value of < 0 implies higher benefit for the privileged group and a value > 0 implies higher benefit for the unprivileged group.<br/>
# invalid value encountered in double_scalars
# **Metric:** Disparate Impact<br/>**Message:** Disparate impact (probability of favorable outcome for unprivileged instances / probability of favorable outcome for privileged instances): 0.6837182626266114<br/>**NumPositivePredictionsUnprivileged:** 2431986.0681450004<br/>**NumUnprivileged:** 11638552.790278<br/>**NumPositivePredictionsPrivileged:** 5522200.936671<br/>**NumPrivileged:** 18068715.665896997<br/>**Description:** Computed as the ratio of likelihood of favorable outcome for the unprivileged group to that of the privileged group.<br/>**Ideal:** The ideal value of this metric is 1.0<br/>
# **Metric:** Statistical Parity Difference<br/>**Message:** Statistical parity difference (probability of favorable outcome for unprivileged instances - probability of favorable outcome for privileged instances): -0.09666272571169776<br/>**NumPositivesUnprivileged:** 2431986.0681450004<br/>**NumInstancesUnprivileged:** 11638552.790278<br/>**NumPositivesPrivileged:** 5522200.936671<br/>**NumInstancesPrivileged:** 18068715.665896997<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:**  The ideal value of this metric is 0<br/>
# **Metric:** True Positive Rate Difference<br/>**Message:** True positive rate difference (true positive rate on unprivileged instances - true positive rate on privileged instances): -0.03196097964390998<br/>**NumTruePositivesUnprivileged:** 761162.0772429999<br/>**NumPositivesUnprivileged:** 1227467.23716<br/>**NumTruePositivesPrivileged:** 2959563.295099<br/>**NumPositivesPrivileged:** 4538728.323577999<br/>**Description:** This metric is computed as the difference of true positive rates between the unprivileged and the privileged groups.  The true positive rate is the ratio of true positives to the total number of actual positives for a given group.<br/>**Ideal:** The ideal value is 0. A value of < 0 implies higher benefit for the privileged group and a value > 0 implies higher benefit for the unprivileged group.<br/>
# **Metric:** Theil Index<br/>**Message:** Theil index (generalized entropy index with alpha = 1): 0.0974722774525154<br/>**Description:** Computed as the generalized entropy of benefit for all individuals in the dataset, with alpha = 1. It measures the inequality in benefit allocation for individuals.<br/>**Ideal:** A value of 0 implies perfect fairness.<br/>
# **Metric:** Accuracy<br/>**Message:** Classification accuracy (ACC): 0.8058995033742516<br/>**NumTruePositives:** 0.0<br/>**NumTrueNegatives:** 23941072.895437002<br/>**NumPositives:** 5766195.560737999<br/>**NumNegatives:** 23941072.895437002<br/>**Description:** Computed as (true positive count + true negative count)/(positive_count + negative_count).<br/>**Ideal:** The ideal value of this metric is 1.0<br/>

# %% [markdown]
# ### [2.4.](#Contents) Dataset Panel20-Panel20

# %%
print("")
print("Dataset: Panel20-Panel20")
print("-------------")
# Out:
# Dataset: Panel20-Panel20
# -------------

# %% [markdown]
# #### [2.4.1.](#Contents) Original Dataset

# %%
bm.predicted_attribute = ''
bm.protected_attributes = ['RACE']
bm.features_to_keep = []
bm.favorable_class = 1
bm.privileged_class = 1
bm.unprivileged_class = 0
bm.dropped_attributes = []
bm.na_values = []
bm.training_size = 5.0    
bm.test_size = 2.0
bm.validation_size = 3.0
bm.total_size = bm.training_size + bm.test_size + bm.validation_size
bm.categorical_features = []
bm.default_mappings = None

# %% [markdown]
# Load dataset

# %%
bm.resource = "" 
bm.dataset_original = MEPSDataset20()

# %%
bm.dataset_original_train, bm.dataset_original_valid, bm.dataset_original_test = bm.dataset_original.split([bm.training_size/bm.total_size, (bm.training_size + bm.validation_size)/bm.total_size], shuffle=True)

# %%
bm.privileged_groups = [{bm.protected_attributes[0] : bm.privileged_class}]
bm.unprivileged_groups = [{bm.protected_attributes[0] : bm.unprivileged_class}]

# %%
bm.init_new_result("Original", "", "Panel20-Panel20", "", "")
bm.measure_bias("balanced_accuracy", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("mean_difference", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("average_odds_difference", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("disparate_impact", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("statistical_parity_difference", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("equal_opportunity_difference", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("theil_index", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("accuracy", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
# Out:
# **Metric:** Mean Difference<br/>**Message:** Mean difference (mean label value on unprivileged instances - mean label value on privileged instances): -0.11651907132545597<br/>**NumPositivesUnprivileged:** 1770587.345658<br/>**NumInstancesUnprivileged:** 13114835.808657<br/>**NumPositivesPrivileged:** 4848224.616606<br/>**NumInstancesPrivileged:** 19275279.532123<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:** The ideal value of this metric is 0.0<br/>
# **Metric:** Disparate Impact<br/>**Message:** Disparate impact (probability of favorable outcome for unprivileged instances / probability of favorable outcome for privileged instances): 0.5367504915245015<br/>**NumPositivePredictionsUnprivileged:** 1770587.345658<br/>**NumUnprivileged:** 13114835.808657<br/>**NumPositivePredictionsPrivileged:** 4848224.616606<br/>**NumPrivileged:** 19275279.532123<br/>**Description:** Computed as the ratio of rate of favorable outcome for the unprivileged group to that of the privileged group.<br/>**Ideal:** The ideal value of this metric is 1.0 A value < 1 implies higher benefit for the privileged group and a value >1 implies a higher benefit for the unprivileged group.<br/>
# **Metric:** Statistical Parity Difference<br/>**Message:** Statistical parity difference (probability of favorable outcome for unprivileged instances - probability of favorable outcome for privileged instances): -0.11651907132545597<br/>**NumPositivesUnprivileged:** 1770587.345658<br/>**NumInstancesUnprivileged:** 13114835.808657<br/>**NumPositivesPrivileged:** 4848224.616606<br/>**NumInstancesPrivileged:** 19275279.532123<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:**  The ideal value of this metric is 0<br/>

# %% [markdown]
# ##### [2.4.1.1.](#Contents) Original Dataset: Classifier LogisticRegression, Parameters: solver='liblinear', random_state=1

# %%
print("")
print("Original Dataset: Classifier LogisticRegression, Parameters: solver='liblinear', random_state=1")
print("-------------")
# Out:
# Original Dataset: Classifier LogisticRegression, Parameters: solver='liblinear', random_state=1
# -------------

# %% [markdown]
# Train the model from the original train data

# %%
classifier = LogisticRegression(solver='liblinear', random_state=1)
model_original_train = bm.train(bm.dataset_original_train,  classifier, without_weight=False)

# %% [markdown]
# ###### [2.4.1.1.1.](#Contents) Original Dataset: Bias Metrics

# %%
print("Original Bias Metrics")
# Out:
# Original Bias Metrics

# %%
dataset_original_train_pred = bm.dataset_original_train.copy(deepcopy=True)
dataset_original_valid_pred = bm.dataset_original_valid.copy(deepcopy=True)
dataset_original_test_pred = bm.dataset_original_test.copy(deepcopy=True)

# %%
standard_scaler = StandardScaler()
dataset_original_train_pred_features = standard_scaler.fit_transform(bm.dataset_original_train.features)
dataset_original_valid_pred_features = standard_scaler.fit_transform(bm.dataset_original_valid.features)
dataset_original_test_pred_features = standard_scaler.fit_transform(bm.dataset_original_test.features)

# %%
dataset_original_train_pred = bm.create_predicted_dataset(dataset_original_train_pred, model_original_train)
dataset_original_valid_pred = bm.create_predicted_dataset(dataset_original_valid_pred, model_original_train)
dataset_original_test_pred = bm.create_predicted_dataset(dataset_original_test_pred, model_original_train)

# %%
pos_ind = np.where(model_original_train.classes_ == bm.dataset_original_train.favorable_label)[0][0]
dataset_original_train_pred.scores = model_original_train.predict_proba(dataset_original_train_pred_features)[:,pos_ind].reshape(-1,1)
dataset_original_valid_pred.scores = model_original_train.predict_proba(dataset_original_valid_pred_features)[:,pos_ind].reshape(-1,1)
dataset_original_test_pred.scores = model_original_train.predict_proba(dataset_original_test_pred_features)[:,pos_ind].reshape(-1,1)

# %%
bm.init_new_result("Original", "", "Panel20-Panel20", "LogisticRegression", "solver='liblinear', random_state=1")

# %%
bm.measure_bias("balanced_accuracy", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train,  )
bm.measure_bias("mean_difference", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train,  )
bm.measure_bias("average_odds_difference", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train, plot_threshold=True, )
bm.measure_bias("disparate_impact", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train, plot_threshold=True, )
bm.measure_bias("statistical_parity_difference", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train,  )
bm.measure_bias("equal_opportunity_difference", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train,  )
bm.measure_bias("theil_index", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train,  )
bm.measure_bias("accuracy", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups,   )
# Out:
# **Metric:** Balanced Accuracy<br/>**Message:** Balanced Classification accuracy (BACC): 0.744711666966455<br/>**TruePositiveRateUnprivileged:** 0.0<br/>**TrueNegativeRateUnprivileged:** 1.0<br/>**TruePositiveRatePrivileged:** 0.0<br/>**TrueNegativeRatePrivileged:** 1.0<br/>**Description:** Return the balanced accuracy of the ratios of true positives and true negatives examples in the dataset, :math:`0.5 * (TPR + TNR)`,  optionally conditioned on protected attributes.<br/>**Ideal:**  The ideal value of this metric is 1<br/>
# **Metric:** Mean Difference<br/>**Message:** Mean difference (mean label value on unprivileged instances - mean label value on privileged instances): -0.23638092727952795<br/>**NumPositivesUnprivileged:** 1770587.345658<br/>**NumInstancesUnprivileged:** 13114835.808657<br/>**NumPositivesPrivileged:** 4848224.616606<br/>**NumInstancesPrivileged:** 19275279.532123<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:** The ideal value of this metric is 0.0<br/>
# **Metric:** Average Odds Difference<br/>**Message:** Average odds difference (average of TPR difference and FPR difference, 0 = equality of odds): -0.1829061623247951<br/>**NumFalsePositivesUnprivileged:** 1861525.2983869999<br/>**NumNegativesUnprivileged:** 11344248.462999001<br/>**NumTruePositivesUnprivileged:** 1101638.532807<br/>**NumPositivesUnprivileged:** 1770587.345658<br/>**NumFalsePositivesPrivileged:** 5009040.5137990005<br/>**NumNegativesPrivileged:** 14427054.915516999<br/>**NumTruePositivesPrivileged:** 3902321.40167<br/>**NumPositivesPrivileged:** 4848224.616606<br/>**Description:** Computed as average difference of false positive rate (false positives / negatives) and true positive rate (true positives / positives) between unprivileged and privileged groups.<br/>**Ideal:** The ideal value of this metric is 0.  A value of < 0 implies higher benefit for the privileged group and a value > 0 implies higher benefit for the unprivileged group.<br/>
# invalid value encountered in double_scalars
# **Metric:** Disparate Impact<br/>**Message:** Disparate impact (probability of favorable outcome for unprivileged instances / probability of favorable outcome for privileged instances): 0.48870795591118743<br/>**NumPositivePredictionsUnprivileged:** 2963163.8311940003<br/>**NumUnprivileged:** 13114835.808657<br/>**NumPositivePredictionsPrivileged:** 8911361.915468998<br/>**NumPrivileged:** 19275279.532123<br/>**Description:** Computed as the ratio of likelihood of favorable outcome for the unprivileged group to that of the privileged group.<br/>**Ideal:** The ideal value of this metric is 1.0<br/>
# **Metric:** Statistical Parity Difference<br/>**Message:** Statistical parity difference (probability of favorable outcome for unprivileged instances - probability of favorable outcome for privileged instances): -0.23638092727952795<br/>**NumPositivesUnprivileged:** 2963163.8311940003<br/>**NumInstancesUnprivileged:** 13114835.808657<br/>**NumPositivesPrivileged:** 8911361.915468998<br/>**NumInstancesPrivileged:** 19275279.532123<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:**  The ideal value of this metric is 0<br/>
# **Metric:** True Positive Rate Difference<br/>**Message:** True positive rate difference (true positive rate on unprivileged instances - true positive rate on privileged instances): -0.182708801898136<br/>**NumTruePositivesUnprivileged:** 1101638.532807<br/>**NumPositivesUnprivileged:** 1770587.345658<br/>**NumTruePositivesPrivileged:** 3902321.40167<br/>**NumPositivesPrivileged:** 4848224.616606<br/>**Description:** This metric is computed as the difference of true positive rates between the unprivileged and the privileged groups.  The true positive rate is the ratio of true positives to the total number of actual positives for a given group.<br/>**Ideal:** The ideal value is 0. A value of < 0 implies higher benefit for the privileged group and a value > 0 implies higher benefit for the unprivileged group.<br/>
# **Metric:** Theil Index<br/>**Message:** Theil index (generalized entropy index with alpha = 1): 0.09809142408127253<br/>**Description:** Computed as the generalized entropy of benefit for all individuals in the dataset, with alpha = 1. It measures the inequality in benefit allocation for individuals.<br/>**Ideal:** A value of 0 implies perfect fairness.<br/>
# **Metric:** Accuracy<br/>**Message:** Classification accuracy (ACC): 0.7956533376733381<br/>**NumTruePositives:** 0.0<br/>**NumTrueNegatives:** 25771303.378516<br/>**NumPositives:** 6618811.962264<br/>**NumNegatives:** 25771303.378516<br/>**Description:** Computed as (true positive count + true negative count)/(positive_count + negative_count).<br/>**Ideal:** The ideal value of this metric is 1.0<br/>

# %% [markdown]
# #### [2.4.2.](#Contents) Mitigate Bias using Reweighing

# %%
print("")
print("Mitigate Bias using Reweighing")
print("-------------")
mitigation_method = bm.create_mitigation_method(Reweighing, )
mitigation_method = mitigation_method.fit(bm.dataset_original_train, )
dataset_mitigated_train = mitigation_method.transform(bm.dataset_original_train)
dataset_mitigated_valid = mitigation_method.transform(bm.dataset_original_valid)
dataset_mitigated_test = bm.dataset_original_test
# Out:
# Mitigate Bias using Reweighing
# -------------

# %% [markdown]
# ##### [2.4.2.1.](#Contents) After-mitigation Dataset: Classifier LogisticRegression, Parameters: solver='liblinear', random_state=1

# %%
print("")
print("After-mitigation Training: LogisticRegression, Parameters: solver='liblinear', random_state=1")
print("-------------")
# Out:
# After-mitigation Training: LogisticRegression, Parameters: solver='liblinear', random_state=1
# -------------

# %% [markdown]
# Train the model from the after-mitigation train data

# %%
classifier = LogisticRegression(solver='liblinear', random_state=1)
model_mitigated_train = bm.train(dataset_mitigated_train,  classifier, without_weight=False)

# %% [markdown]
# ###### [2.4.2.1.1.](#Contents) After-mitigation: Bias Metrics

# %%
print("After-mitigation Metrics")
dataset_mitigated_train_pred = bm.create_predicted_dataset(dataset_mitigated_train, model_mitigated_train)
dataset_mitigated_valid_pred = bm.create_predicted_dataset(dataset_mitigated_valid, model_mitigated_train)
dataset_mitigated_test_pred = bm.create_predicted_dataset(dataset_mitigated_test, model_mitigated_train)
# Out:
# After-mitigation Metrics

# %%
bm.init_new_result("Reweighing", "", "Panel20-Panel20", "LogisticRegression", "solver='liblinear', random_state=1")

# %%
bm.measure_bias("balanced_accuracy", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("mean_difference", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("average_odds_difference", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train, plot_threshold=True, )
bm.measure_bias("disparate_impact", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train, plot_threshold=True, )
bm.measure_bias("statistical_parity_difference", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("equal_opportunity_difference", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("theil_index", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("accuracy", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups,   )
# Out:
# **Metric:** Balanced Accuracy<br/>**Message:** Balanced Classification accuracy (BACC): 0.735988922981972<br/>**TruePositiveRateUnprivileged:** 0.0<br/>**TrueNegativeRateUnprivileged:** 1.0<br/>**TruePositiveRatePrivileged:** 0.0<br/>**TrueNegativeRatePrivileged:** 1.0<br/>**Description:** Return the balanced accuracy of the ratios of true positives and true negatives examples in the dataset, :math:`0.5 * (TPR + TNR)`,  optionally conditioned on protected attributes.<br/>**Ideal:**  The ideal value of this metric is 1<br/>
# **Metric:** Mean Difference<br/>**Message:** Mean difference (mean label value on unprivileged instances - mean label value on privileged instances): -0.04323622483085021<br/>**NumPositivesUnprivileged:** 1770587.345658<br/>**NumInstancesUnprivileged:** 13114835.808657<br/>**NumPositivesPrivileged:** 4848224.616606<br/>**NumInstancesPrivileged:** 19275279.532123<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:** The ideal value of this metric is 0.0<br/>
# **Metric:** Average Odds Difference<br/>**Message:** Average odds difference (average of TPR difference and FPR difference, 0 = equality of odds): 0.006504485118958306<br/>**NumFalsePositivesUnprivileged:** 2505053.1988810003<br/>**NumNegativesUnprivileged:** 11344248.462999001<br/>**NumTruePositivesUnprivileged:** 1209623.112404<br/>**NumPositivesUnprivileged:** 1770587.345658<br/>**NumFalsePositivesPrivileged:** 2971992.526927<br/>**NumNegativesPrivileged:** 14427054.915516999<br/>**NumTruePositivesPrivileged:** 3320972.377905<br/>**NumPositivesPrivileged:** 4848224.616606<br/>**Description:** Computed as average difference of false positive rate (false positives / negatives) and true positive rate (true positives / positives) between unprivileged and privileged groups.<br/>**Ideal:** The ideal value of this metric is 0.  A value of < 0 implies higher benefit for the privileged group and a value > 0 implies higher benefit for the unprivileged group.<br/>
# divide by zero encountered in double_scalars
# invalid value encountered in double_scalars
# **Metric:** Disparate Impact<br/>**Message:** Disparate impact (probability of favorable outcome for unprivileged instances / probability of favorable outcome for privileged instances): 0.8675679378271371<br/>**NumPositivePredictionsUnprivileged:** 3714676.3112850003<br/>**NumUnprivileged:** 13114835.808657<br/>**NumPositivePredictionsPrivileged:** 6292964.904832<br/>**NumPrivileged:** 19275279.532123<br/>**Description:** Computed as the ratio of likelihood of favorable outcome for the unprivileged group to that of the privileged group.<br/>**Ideal:** The ideal value of this metric is 1.0<br/>
# **Metric:** Statistical Parity Difference<br/>**Message:** Statistical parity difference (probability of favorable outcome for unprivileged instances - probability of favorable outcome for privileged instances): -0.04323622483085021<br/>**NumPositivesUnprivileged:** 3714676.3112850003<br/>**NumInstancesUnprivileged:** 13114835.808657<br/>**NumPositivesPrivileged:** 6292964.904832<br/>**NumInstancesPrivileged:** 19275279.532123<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:**  The ideal value of this metric is 0<br/>
# **Metric:** True Positive Rate Difference<br/>**Message:** True positive rate difference (true positive rate on unprivileged instances - true positive rate on privileged instances): -0.0018111306690438145<br/>**NumTruePositivesUnprivileged:** 1209623.112404<br/>**NumPositivesUnprivileged:** 1770587.345658<br/>**NumTruePositivesPrivileged:** 3320972.377905<br/>**NumPositivesPrivileged:** 4848224.616606<br/>**Description:** This metric is computed as the difference of true positive rates between the unprivileged and the privileged groups.  The true positive rate is the ratio of true positives to the total number of actual positives for a given group.<br/>**Ideal:** The ideal value is 0. A value of < 0 implies higher benefit for the privileged group and a value > 0 implies higher benefit for the unprivileged group.<br/>
# **Metric:** Theil Index<br/>**Message:** Theil index (generalized entropy index with alpha = 1): 0.10490376608267027<br/>**Description:** Computed as the generalized entropy of benefit for all individuals in the dataset, with alpha = 1. It measures the inequality in benefit allocation for individuals.<br/>**Ideal:** A value of 0 implies perfect fairness.<br/>
# **Metric:** Accuracy<br/>**Message:** Classification accuracy (ACC): 0.7956533376733381<br/>**NumTruePositives:** 0.0<br/>**NumTrueNegatives:** 25771303.378516<br/>**NumPositives:** 6618811.962264<br/>**NumNegatives:** 25771303.378516<br/>**Description:** Computed as (true positive count + true negative count)/(positive_count + negative_count).<br/>**Ideal:** The ideal value of this metric is 1.0<br/>

# %% [markdown]
# ### [2.5.](#Contents) Dataset Panel20-Panel21

# %%
print("")
print("Dataset: Panel20-Panel21")
print("-------------")
# Out:
# Dataset: Panel20-Panel21
# -------------

# %% [markdown]
# #### [2.5.1.](#Contents) Original Dataset

# %%
bm.predicted_attribute = ''
bm.protected_attributes = ['RACE']
bm.features_to_keep = []
bm.favorable_class = 1
bm.privileged_class = 1
bm.unprivileged_class = 0
bm.dropped_attributes = []
bm.na_values = []
bm.training_size = 5.0    
bm.test_size = 2.0
bm.validation_size = 3.0
bm.total_size = bm.training_size + bm.test_size + bm.validation_size
bm.categorical_features = []
bm.default_mappings = None

# %% [markdown]
# Load dataset

# %%
bm.resource = "" 
bm.dataset_original = MEPSDataset20()

# %%
bm.dataset_original_train, bm.dataset_original_valid, bm.dataset_original_test = bm.dataset_original.split([bm.training_size/bm.total_size, (bm.training_size + bm.validation_size)/bm.total_size], shuffle=True)

# %%
bm.test_dataset_module = MEPSDataset21()
bm.test_dataset_module = bm.dataset_original_train.align_datasets(bm.test_dataset_module)
_ , _ , bm.dataset_original_test = bm.test_dataset_module.split([bm.training_size/bm.total_size, (bm.training_size + bm.validation_size)/bm.total_size], shuffle=True)

# %%
bm.privileged_groups = [{bm.protected_attributes[0] : bm.privileged_class}]
bm.unprivileged_groups = [{bm.protected_attributes[0] : bm.unprivileged_class}]

# %%
bm.init_new_result("Original", "", "Panel20-Panel21", "", "")
bm.measure_bias("balanced_accuracy", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("mean_difference", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("average_odds_difference", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("disparate_impact", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("statistical_parity_difference", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("equal_opportunity_difference", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("theil_index", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
bm.measure_bias("accuracy", baseline_dataset=bm.dataset_original_test, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups)
# Out:
# **Metric:** Mean Difference<br/>**Message:** Mean difference (mean label value on unprivileged instances - mean label value on privileged instances): -0.1375063267050001<br/>**NumPositivesUnprivileged:** 1369349.268741<br/>**NumInstancesUnprivileged:** 12081515.367310999<br/>**NumPositivesPrivileged:** 4239147.309728<br/>**NumInstancesPrivileged:** 16899210.600426003<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:** The ideal value of this metric is 0.0<br/>
# **Metric:** Disparate Impact<br/>**Message:** Disparate impact (probability of favorable outcome for unprivileged instances / probability of favorable outcome for privileged instances): 0.45183589903888494<br/>**NumPositivePredictionsUnprivileged:** 1369349.268741<br/>**NumUnprivileged:** 12081515.367310999<br/>**NumPositivePredictionsPrivileged:** 4239147.309728<br/>**NumPrivileged:** 16899210.600426003<br/>**Description:** Computed as the ratio of rate of favorable outcome for the unprivileged group to that of the privileged group.<br/>**Ideal:** The ideal value of this metric is 1.0 A value < 1 implies higher benefit for the privileged group and a value >1 implies a higher benefit for the unprivileged group.<br/>
# **Metric:** Statistical Parity Difference<br/>**Message:** Statistical parity difference (probability of favorable outcome for unprivileged instances - probability of favorable outcome for privileged instances): -0.1375063267050001<br/>**NumPositivesUnprivileged:** 1369349.268741<br/>**NumInstancesUnprivileged:** 12081515.367310999<br/>**NumPositivesPrivileged:** 4239147.309728<br/>**NumInstancesPrivileged:** 16899210.600426003<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:**  The ideal value of this metric is 0<br/>

# %% [markdown]
# ##### [2.5.1.1.](#Contents) Original Dataset: Classifier LogisticRegression, Parameters: solver='liblinear', random_state=1

# %%
print("")
print("Original Dataset: Classifier LogisticRegression, Parameters: solver='liblinear', random_state=1")
print("-------------")
# Out:
# Original Dataset: Classifier LogisticRegression, Parameters: solver='liblinear', random_state=1
# -------------

# %% [markdown]
# Train the model from the original train data

# %%
classifier = LogisticRegression(solver='liblinear', random_state=1)
model_original_train = bm.train(bm.dataset_original_train,  classifier, without_weight=False)

# %% [markdown]
# ###### [2.5.1.1.1.](#Contents) Original Dataset: Bias Metrics

# %%
print("Original Bias Metrics")
# Out:
# Original Bias Metrics

# %%
dataset_original_train_pred = bm.dataset_original_train.copy(deepcopy=True)
dataset_original_valid_pred = bm.dataset_original_valid.copy(deepcopy=True)
dataset_original_test_pred = bm.dataset_original_test.copy(deepcopy=True)

# %%
standard_scaler = StandardScaler()
dataset_original_train_pred_features = standard_scaler.fit_transform(bm.dataset_original_train.features)
dataset_original_valid_pred_features = standard_scaler.fit_transform(bm.dataset_original_valid.features)
dataset_original_test_pred_features = standard_scaler.fit_transform(bm.dataset_original_test.features)

# %%
dataset_original_train_pred = bm.create_predicted_dataset(dataset_original_train_pred, model_original_train)
dataset_original_valid_pred = bm.create_predicted_dataset(dataset_original_valid_pred, model_original_train)
dataset_original_test_pred = bm.create_predicted_dataset(dataset_original_test_pred, model_original_train)

# %%
pos_ind = np.where(model_original_train.classes_ == bm.dataset_original_train.favorable_label)[0][0]
dataset_original_train_pred.scores = model_original_train.predict_proba(dataset_original_train_pred_features)[:,pos_ind].reshape(-1,1)
dataset_original_valid_pred.scores = model_original_train.predict_proba(dataset_original_valid_pred_features)[:,pos_ind].reshape(-1,1)
dataset_original_test_pred.scores = model_original_train.predict_proba(dataset_original_test_pred_features)[:,pos_ind].reshape(-1,1)

# %%
bm.init_new_result("Original", "", "Panel20-Panel21", "LogisticRegression", "solver='liblinear', random_state=1")

# %%
bm.measure_bias("balanced_accuracy", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train,  )
bm.measure_bias("mean_difference", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train,  )
bm.measure_bias("average_odds_difference", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train, plot_threshold=True, )
bm.measure_bias("disparate_impact", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train, plot_threshold=True, )
bm.measure_bias("statistical_parity_difference", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train,  )
bm.measure_bias("equal_opportunity_difference", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train,  )
bm.measure_bias("theil_index", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_original_train,  )
bm.measure_bias("accuracy", baseline_dataset=bm.dataset_original_test, predicted_dataset=dataset_original_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups,   )
# Out:
# **Metric:** Balanced Accuracy<br/>**Message:** Balanced Classification accuracy (BACC): 0.7413151734922109<br/>**TruePositiveRateUnprivileged:** 0.0<br/>**TrueNegativeRateUnprivileged:** 1.0<br/>**TruePositiveRatePrivileged:** 0.0<br/>**TrueNegativeRatePrivileged:** 1.0<br/>**Description:** Return the balanced accuracy of the ratios of true positives and true negatives examples in the dataset, :math:`0.5 * (TPR + TNR)`,  optionally conditioned on protected attributes.<br/>**Ideal:**  The ideal value of this metric is 1<br/>
# **Metric:** Mean Difference<br/>**Message:** Mean difference (mean label value on unprivileged instances - mean label value on privileged instances): -0.2652879615708505<br/>**NumPositivesUnprivileged:** 1369349.268741<br/>**NumInstancesUnprivileged:** 12081515.367310999<br/>**NumPositivesPrivileged:** 4239147.309728<br/>**NumInstancesPrivileged:** 16899210.600426003<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:** The ideal value of this metric is 0.0<br/>
# **Metric:** Average Odds Difference<br/>**Message:** Average odds difference (average of TPR difference and FPR difference, 0 = equality of odds): -0.1962489889576144<br/>**NumFalsePositivesUnprivileged:** 1257836.0971900001<br/>**NumNegativesUnprivileged:** 10712166.09857<br/>**NumTruePositivesUnprivileged:** 786320.668621<br/>**NumPositivesUnprivileged:** 1369349.268741<br/>**NumFalsePositivesPrivileged:** 4129238.982144<br/>**NumNegativesPrivileged:** 12660063.290698<br/>**NumTruePositivesPrivileged:** 3213214.739698<br/>**NumPositivesPrivileged:** 4239147.309728<br/>**Description:** Computed as average difference of false positive rate (false positives / negatives) and true positive rate (true positives / positives) between unprivileged and privileged groups.<br/>**Ideal:** The ideal value of this metric is 0.  A value of < 0 implies higher benefit for the privileged group and a value > 0 implies higher benefit for the unprivileged group.<br/>
# invalid value encountered in double_scalars
# **Metric:** Disparate Impact<br/>**Message:** Disparate impact (probability of favorable outcome for unprivileged instances / probability of favorable outcome for privileged instances): 0.3894197631770931<br/>**NumPositivePredictionsUnprivileged:** 2044156.765811<br/>**NumUnprivileged:** 12081515.367310999<br/>**NumPositivePredictionsPrivileged:** 7342453.721842<br/>**NumPrivileged:** 16899210.600426003<br/>**Description:** Computed as the ratio of likelihood of favorable outcome for the unprivileged group to that of the privileged group.<br/>**Ideal:** The ideal value of this metric is 1.0<br/>
# **Metric:** Statistical Parity Difference<br/>**Message:** Statistical parity difference (probability of favorable outcome for unprivileged instances - probability of favorable outcome for privileged instances): -0.2652879615708505<br/>**NumPositivesUnprivileged:** 2044156.765811<br/>**NumInstancesUnprivileged:** 12081515.367310999<br/>**NumPositivesPrivileged:** 7342453.721842<br/>**NumInstancesPrivileged:** 16899210.600426003<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:**  The ideal value of this metric is 0<br/>
# **Metric:** True Positive Rate Difference<br/>**Message:** True positive rate difference (true positive rate on unprivileged instances - true positive rate on privileged instances): -0.18375665717005363<br/>**NumTruePositivesUnprivileged:** 786320.668621<br/>**NumPositivesUnprivileged:** 1369349.268741<br/>**NumTruePositivesPrivileged:** 3213214.739698<br/>**NumPositivesPrivileged:** 4239147.309728<br/>**Description:** This metric is computed as the difference of true positive rates between the unprivileged and the privileged groups.  The true positive rate is the ratio of true positives to the total number of actual positives for a given group.<br/>**Ideal:** The ideal value is 0. A value of < 0 implies higher benefit for the privileged group and a value > 0 implies higher benefit for the unprivileged group.<br/>
# **Metric:** Theil Index<br/>**Message:** Theil index (generalized entropy index with alpha = 1): 0.09688418276857676<br/>**Description:** Computed as the generalized entropy of benefit for all individuals in the dataset, with alpha = 1. It measures the inequality in benefit allocation for individuals.<br/>**Ideal:** A value of 0 implies perfect fairness.<br/>
# **Metric:** Accuracy<br/>**Message:** Classification accuracy (ACC): 0.8064749452890622<br/>**NumTruePositives:** 0.0<br/>**NumTrueNegatives:** 23372229.389268<br/>**NumPositives:** 5608496.578469<br/>**NumNegatives:** 23372229.389268<br/>**Description:** Computed as (true positive count + true negative count)/(positive_count + negative_count).<br/>**Ideal:** The ideal value of this metric is 1.0<br/>

# %% [markdown]
# #### [2.5.2.](#Contents) Mitigate Bias using Reweighing

# %%
print("")
print("Mitigate Bias using Reweighing")
print("-------------")
mitigation_method = bm.create_mitigation_method(Reweighing, )
mitigation_method = mitigation_method.fit(bm.dataset_original_train, )
dataset_mitigated_train = mitigation_method.transform(bm.dataset_original_train)
dataset_mitigated_valid = mitigation_method.transform(bm.dataset_original_valid)
dataset_mitigated_test = bm.dataset_original_test
# Out:
# Mitigate Bias using Reweighing
# -------------

# %% [markdown]
# ##### [2.5.2.1.](#Contents) After-mitigation Dataset: Classifier LogisticRegression, Parameters: solver='liblinear', random_state=1

# %%
print("")
print("After-mitigation Training: LogisticRegression, Parameters: solver='liblinear', random_state=1")
print("-------------")
# Out:
# After-mitigation Training: LogisticRegression, Parameters: solver='liblinear', random_state=1
# -------------

# %% [markdown]
# Train the model from the after-mitigation train data

# %%
classifier = LogisticRegression(solver='liblinear', random_state=1)
model_mitigated_train = bm.train(dataset_mitigated_train,  classifier, without_weight=False)

# %% [markdown]
# ###### [2.5.2.1.1.](#Contents) After-mitigation: Bias Metrics

# %%
print("After-mitigation Metrics")
dataset_mitigated_train_pred = bm.create_predicted_dataset(dataset_mitigated_train, model_mitigated_train)
dataset_mitigated_valid_pred = bm.create_predicted_dataset(dataset_mitigated_valid, model_mitigated_train)
dataset_mitigated_test_pred = bm.create_predicted_dataset(dataset_mitigated_test, model_mitigated_train)
# Out:
# After-mitigation Metrics

# %%
bm.init_new_result("Reweighing", "", "Panel20-Panel21", "LogisticRegression", "solver='liblinear', random_state=1")

# %%
bm.measure_bias("balanced_accuracy", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("mean_difference", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("average_odds_difference", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train, plot_threshold=True, )
bm.measure_bias("disparate_impact", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train, plot_threshold=True, )
bm.measure_bias("statistical_parity_difference", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("equal_opportunity_difference", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("theil_index", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups, optimal_threshold=True, model=model_mitigated_train,  )
bm.measure_bias("accuracy", baseline_dataset=dataset_mitigated_test, predicted_dataset=dataset_mitigated_test_pred, privileged_groups=bm.privileged_groups, unprivileged_groups=bm.unprivileged_groups,   )
# Out:
# **Metric:** Balanced Accuracy<br/>**Message:** Balanced Classification accuracy (BACC): 0.7350770180539116<br/>**TruePositiveRateUnprivileged:** 0.0<br/>**TrueNegativeRateUnprivileged:** 1.0<br/>**TruePositiveRatePrivileged:** 0.0<br/>**TrueNegativeRatePrivileged:** 1.0<br/>**Description:** Return the balanced accuracy of the ratios of true positives and true negatives examples in the dataset, :math:`0.5 * (TPR + TNR)`,  optionally conditioned on protected attributes.<br/>**Ideal:**  The ideal value of this metric is 1<br/>
# **Metric:** Mean Difference<br/>**Message:** Mean difference (mean label value on unprivileged instances - mean label value on privileged instances): -0.10402730327914744<br/>**NumPositivesUnprivileged:** 1369349.268741<br/>**NumInstancesUnprivileged:** 12081515.367310999<br/>**NumPositivesPrivileged:** 4239147.309728<br/>**NumInstancesPrivileged:** 16899210.600426003<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:** The ideal value of this metric is 0.0<br/>
# **Metric:** Average Odds Difference<br/>**Message:** Average odds difference (average of TPR difference and FPR difference, 0 = equality of odds): -0.03264548471758168<br/>**NumFalsePositivesUnprivileged:** 2145303.3034429997<br/>**NumNegativesUnprivileged:** 10712166.09857<br/>**NumTruePositivesUnprivileged:** 928668.744418<br/>**NumPositivesUnprivileged:** 1369349.268741<br/>**NumFalsePositivesPrivileged:** 3092639.4029139997<br/>**NumNegativesPrivileged:** 12660063.290698<br/>**NumTruePositivesPrivileged:** 2965106.8976229997<br/>**NumPositivesPrivileged:** 4239147.309728<br/>**Description:** Computed as average difference of false positive rate (false positives / negatives) and true positive rate (true positives / positives) between unprivileged and privileged groups.<br/>**Ideal:** The ideal value of this metric is 0.  A value of < 0 implies higher benefit for the privileged group and a value > 0 implies higher benefit for the unprivileged group.<br/>
# invalid value encountered in double_scalars
# **Metric:** Disparate Impact<br/>**Message:** Disparate impact (probability of favorable outcome for unprivileged instances / probability of favorable outcome for privileged instances): 0.709796478906213<br/>**NumPositivePredictionsUnprivileged:** 3073972.0478609996<br/>**NumUnprivileged:** 12081515.367310999<br/>**NumPositivePredictionsPrivileged:** 6057746.3005369995<br/>**NumPrivileged:** 16899210.600426003<br/>**Description:** Computed as the ratio of likelihood of favorable outcome for the unprivileged group to that of the privileged group.<br/>**Ideal:** The ideal value of this metric is 1.0<br/>
# **Metric:** Statistical Parity Difference<br/>**Message:** Statistical parity difference (probability of favorable outcome for unprivileged instances - probability of favorable outcome for privileged instances): -0.10402730327914744<br/>**NumPositivesUnprivileged:** 3073972.0478609996<br/>**NumInstancesUnprivileged:** 12081515.367310999<br/>**NumPositivesPrivileged:** 6057746.3005369995<br/>**NumInstancesPrivileged:** 16899210.600426003<br/>**Description:** Computed as the difference of the rate of favorable outcomes received by the unprivileged group to the privileged group.<br/>**Ideal:**  The ideal value of this metric is 0<br/>
# **Metric:** True Positive Rate Difference<br/>**Message:** True positive rate difference (true positive rate on unprivileged instances - true positive rate on privileged instances): -0.021275805130433922<br/>**NumTruePositivesUnprivileged:** 928668.744418<br/>**NumPositivesUnprivileged:** 1369349.268741<br/>**NumTruePositivesPrivileged:** 2965106.8976229997<br/>**NumPositivesPrivileged:** 4239147.309728<br/>**Description:** This metric is computed as the difference of true positive rates between the unprivileged and the privileged groups.  The true positive rate is the ratio of true positives to the total number of actual positives for a given group.<br/>**Ideal:** The ideal value is 0. A value of < 0 implies higher benefit for the privileged group and a value > 0 implies higher benefit for the unprivileged group.<br/>
# **Metric:** Theil Index<br/>**Message:** Theil index (generalized entropy index with alpha = 1): 0.09813086148905131<br/>**Description:** Computed as the generalized entropy of benefit for all individuals in the dataset, with alpha = 1. It measures the inequality in benefit allocation for individuals.<br/>**Ideal:** A value of 0 implies perfect fairness.<br/>
# **Metric:** Accuracy<br/>**Message:** Classification accuracy (ACC): 0.8064749452890622<br/>**NumTruePositives:** 0.0<br/>**NumTrueNegatives:** 23372229.389268<br/>**NumPositives:** 5608496.578469<br/>**NumNegatives:** 23372229.389268<br/>**Description:** Computed as (true positive count + true negative count)/(positive_count + negative_count).<br/>**Ideal:** The ideal value of this metric is 1.0<br/>

# %% [markdown]
# ### [2.6.](#Contents) Summary

# %%
table = bm.display_summary()
table.style.set_caption("Worst = White, Best = Green, Mid = Yellow") \
    .apply(bm.highlight_fairest_values, axis=1)
# Out:
# **Description:**<br/>Original Data size: 17570</br>Predicted attribute: </br>Protected attributes: RACE</br>Favourable classes: 1</br>Dropped attributes:  </br>Training data size (ratio): 5.0</br>Test data size (ratio): 2.0</br>Validation data size (ratio): 3.0
# **LogisticRegression:**<details><br/>    Logistic Regression (aka logit, MaxEnt) classifier.<br/><br/>    In the multiclass case, the training algorithm uses the one-vs-rest (OvR)<br/>    scheme if the 'multi_class' option is set to 'ovr', and uses the<br/>    cross-entropy loss if the 'multi_class' option is set to 'multinomial'.<br/>    (Currently the 'multinomial' option is supported only by the 'lbfgs',<br/>    'sag', 'saga' and 'newton-cg' solvers.)<br/><br/>    This class implements regularized logistic regression using the<br/>    'liblinear' library, 'newton-cg', 'sag', 'saga' and 'lbfgs' solvers. **Note<br/>    that regularization is applied by default**. It can handle both dense<br/>    and sparse input. Use C-ordered arrays or CSR matrices containing 64-bit<br/>    floats for optimal performance; any other input format will be converted<br/>    (and copied).<br/><br/>    The 'newton-cg', 'sag', and 'lbfgs' solvers support only L2 regularization<br/>    with primal formulation, or no regularization. The 'liblinear' solver<br/>    supports both L1 and L2 regularization, with a dual formulation only for<br/>    the L2 penalty. The Elastic-Net regularization is only supported by the<br/>    'saga' solver.<br/><br/>    Read more in the :ref:`User Guide <logistic_regression>`.<br/><br/>    Parameters<br/>    ----------<br/>    penalty : {'l1', 'l2', 'elasticnet', 'none'}, default='l2'<br/>        Specify the norm of the penalty:<br/><br/>        - `'none'`: no penalty is added;<br/>        - `'l2'`: add a L2 penalty term and it is the default choice;<br/>        - `'l1'`: add a L1 penalty term;<br/>        - `'elasticnet'`: both L1 and L2 penalty terms are added.<br/><br/>        .. warning::<br/>           Some penalties may not work with some solvers. See the parameter<br/>           `solver` below, to know the compatibility between the penalty and<br/>           solver.<br/><br/>        .. versionadded:: 0.19<br/>           l1 penalty with SAGA solver (allowing 'multinomial' + L1)<br/><br/>    dual : bool, default=False<br/>        Dual or primal formulation. Dual formulation is only implemented for<br/>        l2 penalty with liblinear solver. Prefer dual=False when<br/>        n_samples > n_features.<br/><br/>    tol : float, default=1e-4<br/>        Tolerance for stopping criteria.<br/><br/>    C : float, default=1.0<br/>        Inverse of regularization strength; must be a positive float.<br/>        Like in support vector machines, smaller values specify stronger<br/>        regularization.<br/><br/>    fit_intercept : bool, default=True<br/>        Specifies if a constant (a.k.a. bias or intercept) should be<br/>        added to the decision function.<br/><br/>    intercept_scaling : float, default=1<br/>        Useful only when the solver 'liblinear' is used<br/>        and self.fit_intercept is set to True. In this case, x becomes<br/>        [x, self.intercept_scaling],<br/>        i.e. a "synthetic" feature with constant value equal to<br/>        intercept_scaling is appended to the instance vector.<br/>        The intercept becomes ``intercept_scaling * synthetic_feature_weight``.<br/><br/>        Note! the synthetic feature weight is subject to l1/l2 regularization<br/>        as all other features.<br/>        To lessen the effect of regularization on synthetic feature weight<br/>        (and therefore on the intercept) intercept_scaling has to be increased.<br/><br/>    class_weight : dict or 'balanced', default=None<br/>        Weights associated with classes in the form ``{class_label: weight}``.<br/>        If not given, all classes are supposed to have weight one.<br/><br/>        The "balanced" mode uses the values of y to automatically adjust<br/>        weights inversely proportional to class frequencies in the input data<br/>        as ``n_samples / (n_classes * np.bincount(y))``.<br/><br/>        Note that these weights will be multiplied with sample_weight (passed<br/>        through the fit me ...
# **Reweighing:**<details>Reweighing is a preprocessing technique that Weights the examples in each<br/>    (group, label) combination differently to ensure fairness before<br/>    classification [4]_.<br/><br/>    References:<br/>        .. [4] F. Kamiran and T. Calders,  "Data Preprocessing Techniques for<br/>           Classification without Discrimination," Knowledge and Information<br/>           Systems, 2012.<br/>    </details>
# <style type="text/css">
# #T_e0d59_row0_col3, #T_e0d59_row0_col5, #T_e0d59_row0_col8, #T_e0d59_row0_col9, #T_e0d59_row0_col10, #T_e0d59_row3_col3, #T_e0d59_row3_col5, #T_e0d59_row3_col8, #T_e0d59_row3_col9, #T_e0d59_row3_col10, #T_e0d59_row6_col3, #T_e0d59_row6_col5, #T_e0d59_row6_col8, #T_e0d59_row6_col9, #T_e0d59_row6_col10, #T_e0d59_row7_col4, #T_e0d59_row7_col5, #T_e0d59_row7_col6, #T_e0d59_row7_col7, #T_e0d59_row7_col8, #T_e0d59_row9_col3, #T_e0d59_row9_col5, #T_e0d59_row9_col8, #T_e0d59_row9_col9, #T_e0d59_row9_col10, #T_e0d59_row11_col9, #T_e0d59_row12_col3, #T_e0d59_row12_col5, #T_e0d59_row12_col8, #T_e0d59_row12_col9, #T_e0d59_row12_col10, #T_e0d59_row13_col6 {
#   background-color: #ffffff;
# }
# #T_e0d59_row0_col4, #T_e0d59_row0_col7 {
#   background-color: #ffff01;
# }
# #T_e0d59_row0_col6 {
#   background-color: #ffffbe;
# }
# #T_e0d59_row1_col3, #T_e0d59_row4_col10, #T_e0d59_row5_col4, #T_e0d59_row5_col6, #T_e0d59_row5_col7 {
#   font-weight: bold;
#   background-color: #00ff00;
# }
# #T_e0d59_row1_col4, #T_e0d59_row1_col7 {
#   background-color: #ffff93;
# }
# #T_e0d59_row1_col5 {
#   background-color: #ffff35;
# }
# #T_e0d59_row1_col6 {
#   background-color: #ffffa0;
# }
# #T_e0d59_row1_col8 {
#   background-color: #e6ff00;
# }
# #T_e0d59_row1_col9 {
#   background-color: #ffffc7;
# }
# #T_e0d59_row1_col10, #T_e0d59_row2_col10 {
#   background-color: #13ff00;
# }
# #T_e0d59_row2_col3 {
#   background-color: #03ff00;
# }
# #T_e0d59_row2_col4, #T_e0d59_row2_col7 {
#   background-color: #2fff00;
# }
# #T_e0d59_row2_col5 {
#   background-color: #63ff00;
# }
# #T_e0d59_row2_col6 {
#   background-color: #61ff00;
# }
# #T_e0d59_row2_col8 {
#   background-color: #a9ff00;
# }
# #T_e0d59_row2_col9 {
#   background-color: #ffffd0;
# }
# #T_e0d59_row3_col4, #T_e0d59_row3_col7 {
#   background-color: #9bff00;
# }
# #T_e0d59_row3_col6 {
#   background-color: #ffff6f;
# }
# #T_e0d59_row4_col3, #T_e0d59_row10_col10, #T_e0d59_row11_col10 {
#   background-color: #09ff00;
# }
# #T_e0d59_row4_col4, #T_e0d59_row4_col7 {
#   background-color: #ffff8e;
# }
# #T_e0d59_row4_col5 {
#   background-color: #ffff73;
# }
# #T_e0d59_row4_col6 {
#   background-color: #ffffaf;
# }
# #T_e0d59_row4_col8 {
#   background-color: #ffff31;
# }
# #T_e0d59_row4_col9, #T_e0d59_row10_col9 {
#   background-color: #ffffde;
# }
# #T_e0d59_row5_col3 {
#   background-color: #0cff00;
# }
# #T_e0d59_row5_col5 {
#   background-color: #6fff00;
# }
# #T_e0d59_row5_col8 {
#   background-color: #d3ff00;
# }
# #T_e0d59_row5_col9, #T_e0d59_row12_col6 {
#   background-color: #ffffc2;
# }
# #T_e0d59_row5_col10 {
#   background-color: #00ff00;
# }
# #T_e0d59_row6_col4, #T_e0d59_row6_col7 {
#   background-color: #efff00;
# }
# #T_e0d59_row6_col6 {
#   background-color: #ffffe1;
# }
# #T_e0d59_row7_col3 {
#   background-color: #06ff00;
# }
# #T_e0d59_row7_col9 {
#   font-weight: bold;
#   background-color: #ffffc2;
# }
# #T_e0d59_row7_col10, #T_e0d59_row8_col10, #T_e0d59_row13_col10, #T_e0d59_row14_col10 {
#   background-color: #02ff00;
# }
# #T_e0d59_row8_col3 {
#   background-color: #0fff00;
# }
# #T_e0d59_row8_col4, #T_e0d59_row8_col7 {
#   background-color: #81ff00;
# }
# #T_e0d59_row8_col5 {
#   background-color: #4aff00;
# }
# #T_e0d59_row8_col6 {
#   background-color: #dbff00;
# }
# #T_e0d59_row8_col8 {
#   background-color: #48ff00;
# }
# #T_e0d59_row8_col9 {
#   background-color: #ffffdb;
# }
# #T_e0d59_row9_col4, #T_e0d59_row9_col7 {
#   background-color: #aeff00;
# }
# #T_e0d59_row9_col6 {
#   background-color: #ffff6e;
# }
# #T_e0d59_row10_col3 {
#   background-color: #08ff00;
# }
# #T_e0d59_row10_col4, #T_e0d59_row10_col7 {
#   background-color: #ffffbb;
# }
# #T_e0d59_row10_col5 {
#   background-color: #ffffb8;
# }
# #T_e0d59_row10_col6 {
#   background-color: #ffff9d;
# }
# #T_e0d59_row10_col8 {
#   background-color: #ffff99;
# }
# #T_e0d59_row11_col3, #T_e0d59_row14_col3 {
#   background-color: #0eff00;
# }
# #T_e0d59_row11_col4, #T_e0d59_row11_col7, #T_e0d59_row13_col3 {
#   background-color: #0aff00;
# }
# #T_e0d59_row11_col5 {
#   font-weight: bold;
#   background-color: #10ff00;
# }
# #T_e0d59_row11_col6 {
#   background-color: #25ff00;
# }
# #T_e0d59_row11_col8 {
#   font-weight: bold;
#   background-color: #05ff00;
# }
# #T_e0d59_row12_col4, #T_e0d59_row12_col7 {
#   background-color: #ddff00;
# }
# #T_e0d59_row13_col4, #T_e0d59_row13_col7 {
#   background-color: #fffffc;
# }
# #T_e0d59_row13_col5 {
#   background-color: #ffffd8;
# }
# #T_e0d59_row13_col8 {
#   background-color: #ffff9b;
# }
# #T_e0d59_row13_col9 {
#   background-color: #ffffd9;
# }
# #T_e0d59_row14_col4, #T_e0d59_row14_col7 {
#   background-color: #92ff00;
# }
# #T_e0d59_row14_col5 {
#   background-color: #4fff00;
# }
# #T_e0d59_row14_col6 {
#   background-color: #c1ff00;
# }
# #T_e0d59_row14_col8 {
#   background-color: #30ff00;
# }
# #T_e0d59_row14_col9 {
#   background-color: #ffffdf;
# }
# </style>
# <table id="T_e0d59">
#   <caption>Worst = White, Best = Green, Mid = Yellow</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e0d59_level0_col0" class="col_heading level0 col0" >Mitigation</th>
#       <th id="T_e0d59_level0_col1" class="col_heading level0 col1" >Dataset</th>
#       <th id="T_e0d59_level0_col2" class="col_heading level0 col2" >Classifier</th>
#       <th id="T_e0d59_level0_col3" class="col_heading level0 col3" >balanced_accuracy</th>
#       <th id="T_e0d59_level0_col4" class="col_heading level0 col4" >mean_difference</th>
#       <th id="T_e0d59_level0_col5" class="col_heading level0 col5" >average_odds_difference</th>
#       <th id="T_e0d59_level0_col6" class="col_heading level0 col6" >disparate_impact</th>
#       <th id="T_e0d59_level0_col7" class="col_heading level0 col7" >statistical_parity_difference</th>
#       <th id="T_e0d59_level0_col8" class="col_heading level0 col8" >equal_opportunity_difference</th>
#       <th id="T_e0d59_level0_col9" class="col_heading level0 col9" >theil_index</th>
#       <th id="T_e0d59_level0_col10" class="col_heading level0 col10" >accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0d59_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_e0d59_row0_col0" class="data row0 col0" >Original</td>
#       <td id="T_e0d59_row0_col1" class="data row0 col1" >Panel19-Panel19(5.0:2.0:3.0)</td>
#       <td id="T_e0d59_row0_col2" class="data row0 col2" ></td>
#       <td id="T_e0d59_row0_col3" class="data row0 col3" >None</td>
#       <td id="T_e0d59_row0_col4" class="data row0 col4" >-0.153251</td>
#       <td id="T_e0d59_row0_col5" class="data row0 col5" >None</td>
#       <td id="T_e0d59_row0_col6" class="data row0 col6" >0.455302</td>
#       <td id="T_e0d59_row0_col7" class="data row0 col7" >-0.153251</td>
#       <td id="T_e0d59_row0_col8" class="data row0 col8" >None</td>
#       <td id="T_e0d59_row0_col9" class="data row0 col9" >None</td>
#       <td id="T_e0d59_row0_col10" class="data row0 col10" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e0d59_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_e0d59_row1_col0" class="data row1 col0" >Original</td>
#       <td id="T_e0d59_row1_col1" class="data row1 col1" >Panel19-Panel19(5.0:2.0:3.0)</td>
#       <td id="T_e0d59_row1_col2" class="data row1 col2" >LogisticRegression
# solver='liblinear', random_state=1</td>
#       <td id="T_e0d59_row1_col3" class="data row1 col3" >0.755588</td>
#       <td id="T_e0d59_row1_col4" class="data row1 col4" >-0.218486</td>
#       <td id="T_e0d59_row1_col5" class="data row1 col5" >-0.128144</td>
#       <td id="T_e0d59_row1_col6" class="data row1 col6" >0.485587</td>
#       <td id="T_e0d59_row1_col7" class="data row1 col7" >-0.218486</td>
#       <td id="T_e0d59_row1_col8" class="data row1 col8" >-0.102933</td>
#       <td id="T_e0d59_row1_col9" class="data row1 col9" >0.093337</td>
#       <td id="T_e0d59_row1_col10" class="data row1 col10" >0.778879</td>
#     </tr>
#     <tr>
#       <th id="T_e0d59_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_e0d59_row2_col0" class="data row2 col0" >Reweighing</td>
#       <td id="T_e0d59_row2_col1" class="data row2 col1" >Panel19-Panel19(5.0:2.0:3.0)</td>
#       <td id="T_e0d59_row2_col2" class="data row2 col2" >LogisticRegression
# solver='liblinear', random_state=1</td>
#       <td id="T_e0d59_row2_col3" class="data row2 col3" >0.751927</td>
#       <td id="T_e0d59_ro

# %%
if get_ipython() is not None:
    get_ipython().magic("%matplotlib inline")

# %%
bm.display_barchart()
